# %%
# Import libraries

import simpy
import random

# Set Simulation Global Variables
PASSENGER_INTERVAL = 5
NUM_FLOORS = 8
#NUM_ELEVATORS = 4
MAX_CAPACITY = 4
MINUTES_IN_DAY = 24 * 60 # Total simulation time in minutes
SIM_TIME = MINUTES_IN_DAY # Total simulation time in minutes

# %%
def get_arrival_rate(current_time_minutes):
    
    """
    Returns the arrival rate (passengers per minute) based on time of day.
    Peak times:
    - 7:30-8:30 AM (450-510 minutes)
    - 12:00-1:00 PM (720-780 minutes) 
    - 5:00-10:00 PM (1020-1320 minutes)
    """
    
    # Convert time to minutes from midnight
    time_of_day = current_time_minutes % 1440
    
    # Morning rush: 7:30-8:30 AM
    if 450 <= time_of_day <= 510:
        return 1  # High arrival rate (1 passenger every 1 minutes on average)
    
    # Lunch rush: 12:00-1:00 PM
    elif 720 <= time_of_day <= 780:
        return 1  # High arrival rate (1 passenger every 1 minutes on average)
    
    # Evening rush: 5:00-10:00 PM
    elif 1020 <= time_of_day <= 1320:
        return 1  # Medium-high arrival rate (1 passenger every 1 minutes on average)
    
    # Off-peak hours
    else:
        return 0.05  # Low arrival rate (1 passenger every 20 minutes on average)

def time_to_string(minutes):
    """Convert minutes from midnight to HH:MM format"""
    hours = int(minutes // 60) % 24
    mins = int(minutes % 60)
    return f"{hours:02d}:{mins:02d}"

# %%
class Passenger:
    def __init__(self, pid, pickup, destination, start_time):
        self.id = pid
        self.pickup = pickup
        self.destination = destination
        self.start_time = start_time  # Track when passenger enters system
    
    def __repr__(self, color = '\033[97m'):         # changes representation of passenger to be easier to read
        return f"{color}P{self.id}({self.pickup} --> {self.destination})"

# %%
def passenger_generator(env, elevator):
    # Start with pid 1
    pid = 1         
    
    while True:
        # Get current arrival rate based on time of day
        current_rate = get_arrival_rate(env.now)
        
        # Calculate inter-arrival time using exponential distribution
        if current_rate > 0:
            inter_arrival_time = random.expovariate(current_rate)
        else:
            # Default to 1 hour if rate is 0 
            inter_arrival_time = 60  
        
        
        
        pickup = random.randint(0, NUM_FLOORS - 1)           # random floor
        destination = random.randint(0, NUM_FLOORS - 1)       # random destination
        while pickup == destination:
            destination = random.randint(0,NUM_FLOORS -1)
        
        
        start_time = env.now  # Record start time
        passenger = Passenger(pid, pickup, destination, start_time) # create the passenger
        current_time_str = time_to_string(env.now)
        print(f"[{current_time_str}] Passenger {pid} appears at floor {pickup}, wants to go to {destination}")
        elevator.request_pickup(passenger)              # request pickup from elevator
        pid +=1


        yield env.timeout(inter_arrival_time)

# %%
class Dispatcher:
    def __init__(self, elevators):
        self.elevators = elevators

    def assign_passenger(self, passenger):
        best_elevator = min(
            self.elevators, key = lambda x: abs(x.floor - passenger.pickup)
        )

        best_elevator.request_pickup(passenger)

# %%
class Elevator:
    def __init__(self, env, num_floors, strategy = "nearest"):
        self.env = env
        self.floor = 0          # Start at ground floor (0)
        self.direction = 'up'   # up or down
        self.num_floors = num_floors # total
        self.pickup_requests = {floor: [] for floor in range(num_floors)}
        self.onboard = []
        self.strategy = strategy
        self.stats = {
            'total_passengers': 0,
            'total_wait_time': 0,
            'total_travel_time': 0
        }

    def log(self, message):
        current_time = time_to_string(self.env.now)
        print(f"    [{current_time}] Elevator floor: {self.floor} | {message}")

    def request_pickup(self, passenger):
        self.pickup_requests[passenger.pickup].append(passenger)
        self.log(f"Passenger {passenger.id} requests a pickup at floor {passenger.pickup}")

    def find_longest_waiting_request(self):
        longest_wait_time = -1
        target_floor = None
        for floor, passengers in self.pickup_requests.items():
            for p in passengers:
                wait_time = self.env.now - p.start_time
                if wait_time > longest_wait_time:
                    longest_wait_time = wait_time
                    target_floor = floor
        return target_floor

    def run_elevator(self):
        while True:
            # 1) Off-load passengers at current floor
            offboarding = [p for p in self.onboard if p.destination == self.floor]
            for p in offboarding:
                self.onboard.remove(p)
                travel_time = self.env.now - p.start_time
                self.stats['total_travel_time'] += travel_time
                self.stats['total_passengers'] += 1
                self.log(f"Dropped off {p} (travel time: {travel_time:.1f} min)")

            # 2) On-board passengers at current floor
            boarding = self.pickup_requests[self.floor]
            for p in boarding:
                if len(self.onboard) < MAX_CAPACITY:
                    self.onboard.append(p)
                    wait_time = self.env.now - p.start_time
                    self.stats['total_wait_time'] += wait_time
                    self.log(f"Picked up {p} (wait time: {wait_time:.1f} min)")
                else:
                    self.log(f"Elevator full, {p} must wait")
            
            self.pickup_requests[self.floor].clear()

            if not any(self.pickup_requests.values()) and not self.onboard:
                #self.log("idle")
                yield self.env.timeout(1)
                continue


            # 3) Move logic based on strategy
            if self.strategy == "longest_wait":
                target_floor = self.find_longest_waiting_request()
    
                if target_floor is not None and target_floor != self.floor:
                    if target_floor > self.floor:
                        self.direction = 'up'
                        self.floor += 1
                    elif target_floor < self.floor:
                        self.direction = 'down'
                        self.floor -= 1
                        self.log(f"Moving {self.direction} toward floor {target_floor}")
                else:
                # No passengers waiting → continue in current direction
                    self.log("No pickups pending, continuing current direction")
                    if self.direction == 'up':
                        if self.floor < self.num_floors - 1:
                            self.floor += 1
                        else:
                            self.direction = 'down'
                            self.floor -= 1
                    else:
                        if self.floor > 0:
                            self.floor -= 1
                        else:
                            self.direction = 'up'
                            self.floor += 1
            else:
            # Default nearest (up/down sweep)
                if self.direction == 'up':
                    if self.floor < self.num_floors - 1:
                        self.floor += 1
                    else:
                        self.direction = 'down'
                        self.floor -= 1
                else:
                    if self.floor > 0:
                        self.floor -= 1
                    else:
                        self.direction = 'up'
                        self.floor += 1
            self.log(f"Moving {self.direction} to floor {self.floor}")


# 4) Wait for travel time (e.g. 1 time-unit per floor)
            yield self.env.timeout(.5)

# %%
class Elevator_Controller:
    def __init__(self, env, NUM_ELEVATORS, NUM_FLOORS):
        self.env = env
        self.elevators = [Elevator(env, NUM_FLOORS) for _ in range(NUM_ELEVATORS)]
        self.dispatcher = Dispatcher(self.elevators)

    def start(self):
        for elevator in self.elevators:
            self.env.process(elevator.run_elevator())

# %%
def print_simulation_stats(elevator):
    """Print simulation statistics"""
    print("\n" + "="*50)
    print("SIMULATION STATISTICS")
    print("="*50)
    print(f"Total passengers served: {elevator.stats['total_passengers']}")
    if elevator.stats['total_passengers'] > 0:
        avg_wait_time = elevator.stats['total_wait_time'] / elevator.stats['total_passengers']
        avg_travel_time = elevator.stats['total_travel_time'] / elevator.stats['total_passengers']
        print(f"Average wait time: {avg_wait_time:.1f} minutes")
        print(f"Average travel time: {avg_travel_time:.1f} minutes")
    print(f"Simulation duration: {SIM_TIME} minutes ({SIM_TIME/60:.1f} hours)")
    print(f"total passengers {[elevator.stats['total_passengers']]}")
    print("="*50)

# %%
# Run the simulation
if __name__ == "__main__":
    random.seed(23)
    env = simpy.Environment()
    elevator = Elevator(env, num_floors=NUM_FLOORS, strategy="longest_wait")  # or "nearest"

    
    # Start both processes
    env.process(passenger_generator(env, elevator))
    env.process(elevator.run_elevator())
    
    print(f"Starting 24-hour elevator simulation...")
    print(f"Simulation will run for {SIM_TIME} minutes ({SIM_TIME/60:.1f} hours)")
    print("-" * 50)
    
    env.run(until=SIM_TIME)
    
    print_simulation_stats(elevator)
# Out:
# Starting 24-hour elevator simulation...
# Simulation will run for 1440 minutes (24.0 hours)
# --------------------------------------------------
# [00:00] Passenger 1 appears at floor 4, wants to go to 1
#     [00:00] Elevator floor: 0 | Passenger 1 requests a pickup at floor 4
#     [00:00] Elevator floor: 1 | Moving up to floor 1
#     [00:00] Elevator floor: 2 | Moving up to floor 2
#     [00:01] Elevator floor: 3 | Moving up to floor 3
#     [00:01] Elevator floor: 4 | Moving up to floor 4
#     [00:02] Elevator floor: 4 | Picked up P1(4 --> 1) (wait time: 2.0 min)
#     [00:02] Elevator floor: 4 | No pickups pending, continuing current direction
#     [00:02] Elevator floor: 5 | Moving up to floor 5
#     [00:02] Elevator floor: 5 | No pickups pending, continuing current direction
#     [00:02] Elevator floor: 6 | Moving up to floor 6
#     [00:03] Elevator floor: 6 | No pickups pending, continuing current direction
#     [00:03] Elevator floor: 7 | Moving up to floor 7
#     [00:03] Elevator floor: 7 | No pickups pending, continuing current direction
#     [00:03] Elevator floor: 6 | Moving down to floor 6
#     [00:04] Elevator floor: 6 | No pickups pending, continuing current direction
#     [00:04] Elevator floor: 5 | Moving down to floor 5
#     [00:04] Elevator floor: 5 | No pickups pending, continuing current direction
#     [00:04] Elevator floor: 4 | Moving down to floor 4
#     [00:05] Elevator floor: 4 | No pickups pending, continuing current direction
#     [00:05] Elevator floor: 3 | Moving down to floor 3
#     [00:05] Elevator floor: 3 | No pickups pending, continuing current direction
#     [00:05] Elevator floor: 2 | Moving down to floor 2
#     [00:06] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:06] Elevator floor: 1 | Moving down to floor 1
#     [00:06] Elevator floor: 1 | Dropped off P1(4 --> 1) (travel time: 6.5 min)
# [00:51] Passenger 2 appears at floor 4, wants to go to 6
#     [00:51] Elevator floor: 1 | Passenger 2 requests a pickup at floor 4
# [00:52] Passenger 3 appears at floor 5, wants to go to 2
#     [00:52] Elevator floor: 1 | Passenger 3 requests a pickup at floor 5
#     [00:52] Elevator floor: 2 | Moving up to floor 2
#     [00:53] Elevator floor: 3 | Moving up to floor 3
#     [00:53] Elevator floor: 4 | Moving up to floor 4
#     [00:54] Elevator floor: 4 | Picked up P2(4 --> 6) (wait time: 2.2 min)
#     [00:54] Elevator floor: 5 | Moving up to floor 5
#     [00:54] Elevator floor: 5 | Picked up P3(5 --> 2) (wait time: 2.4 min)
#     [00:54] Elevator floor: 5 | No pickups pending, continuing current direction
#     [00:54] Elevator floor: 6 | Moving up to floor 6
#     [00:55] Elevator floor: 6 | Dropped off P2(4 --> 6) (travel time: 3.2 min)
#     [00:55] Elevator floor: 6 | No pickups pending, continuing current direction
#     [00:55] Elevator floor: 7 | Moving up to floor 7
#     [00:55] Elevator floor: 7 | No pickups pending, continuing current direction
#     [00:55] Elevator floor: 6 | Moving down to floor 6
#     [00:56] Elevator floor: 6 | No pickups pending, continuing current direction
#     [00:56] Elevator floor: 5 | Moving down to floor 5
#     [00:56] Elevator floor: 5 | No pickups pending, continuing current direction
#     [00:56] Elevator floor: 4 | Moving down to floor 4
#     [00:57] Elevator floor: 4 | No pickups pending, continuing current direction
#     [00:57] Elevator floor: 3 | Moving down to floor 3
#     [00:57] Elevator floor: 3 | No pickups pending, continuing current direction
#     [00:57] Elevator floor: 2 | Moving down to floor 2
#     [00:58] Elevator floor: 2 | Dropped off P3(5 --> 2) (travel time: 5.9 min)
# [01:01] Passenger 4 appears at floor 4, wants to go to 7
#     [01:01] Elevator floor: 2 | Passenger 4 requests a pickup at floor 4
#     [01:02] Elevator floor: 3 | Moving up to floor 3
#     [01:02] Elevator floor: 4 | Moving up to floor 4
#     [01:03] Elevator floor: 4 | Picked up P4(4 --> 7) (wait time: 1.4 min)
#     [01:03] Elevator floor: 4 | No pickups pending, continuing current direction
#     [01:03] Elevator floor: 5 | Moving up to floor 5
#     [01:03] Elevator floor: 5 | No pickups pending, continuing current direction
#     [01:03] Elevator floor: 6 | Moving up to floor 6
#     [01:04] Elevator floor: 6 | No pickups pending, continuing current direction
#     [01:04] Elevator floor: 7 | Moving up to floor 7
#     [01:04] Elevator floor: 7 | Dropped off P4(4 --> 7) (travel time: 2.9 min)
# [01:27] Passenger 5 appears at floor 7, wants to go to 0
#     [01:27] Elevator floor: 7 | Passenger 5 requests a pickup at floor 7
# [01:27] Passenger 6 appears at floor 7, wants to go to 6
#     [01:27] Elevator floor: 7 | Passenger 6 requests a pickup at floor 7
#     [01:28] Elevator floor: 7 | Picked up P5(7 --> 0) (wait time: 1.0 min)
#     [01:28] Elevator floor: 7 | Picked up P6(7 --> 6) (wait time: 0.7 min)
#     [01:28] Elevator floor: 7 | No pickups pending, continuing current direction
#     [01:28] Elevator floor: 6 | Moving down to floor 6
#     [01:29] Elevator floor: 6 | Dropped off P6(7 --> 6) (travel time: 1.2 min)
#     [01:29] Elevator floor: 6 | No pickups pending, continuing current direction
#     [01:29] Elevator floor: 5 | Moving down to floor 5
#     [01:29] Elevator floor: 5 | No pickups pending, continuing current direction
#     [01:29] Elevator floor: 4 | Moving down to floor 4
#     [01:30] Elevator floor: 4 | No pickups pending, continuing current direction
#     [01:30] Elevator floor: 3 | Moving down to floor 3
# [01:30] Passenger 7 appears at floor 6, wants to go to 5
#     [01:30] Elevator floor: 3 | Passenger 7 requests a pickup at floor 6
# [01:30] Passenger 8 appears at floor 3, wants to go to 0
#     [01:30] Elevator floor: 3 | Passenger 8 requests a pickup at floor 3
#     [01:30] Elevator floor: 3 | Picked up P8(3 --> 0) (wait time: 0.0 min)
#     [01:30] Elevator floor: 4 | Moving up to floor 4
#     [01:31] Elevator floor: 5 | Moving up to floor 5
#     [01:31] Elevator floor: 6 | Moving up to floor 6
#     [01:32] Elevator floor: 6 | Picked up P7(6 --> 5) (wait time: 1.9 min)
#     [01:32] Elevator floor: 6 | No pickups pending, continuing current direction
#     [01:32] Elevator floor: 7 | Moving up to floor 7
#     [01:32] Elevator floor: 7 | No pickups pending, continuing current direction
#     [01:32] Elevator floor: 6 | Moving down to floor 6
#     [01:33] Elevator floor: 6 | No pickups pending, continuing current direction
#     [01:33] Elevator floor: 5 | Moving down to floor 5
#     [01:33] Elevator floor: 5 | Dropped off P7(6 --> 5) (travel time: 3.4 min)
#     [01:33] Elevator floor: 5 | No pickups pending, continuing current direction
#     [01:33] Elevator floor: 4 | Moving down to floor 4
#     [01:34] Elevator floor: 4 | No pickups pending, continuing current direction
#     [01:34] Elevator floor: 3 | Moving down to floor 3
#     [01:34] Elevator floor: 3 | No pickups pending, continuing current direction
#     [01:34] Elevator floor: 2 | Moving down to floor 2
#     [01:35] Elevator floor: 2 | No pickups pending, continuing current direction
#     [01:35] Elevator floor: 1 | Moving down to floor 1
#     [01:35] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:35] Elevator floor: 0 | Moving down to floor 0
#     [01:36] Elevator floor: 0 | Dropped off P5(7 --> 0) (travel time: 8.5 min)
#     [01:36] Elevator floor: 0 | Dropped off P8(3 --> 0) (travel time: 5.5 min)
# [01:59] Passenger 9 appears at floor 2, wants to go to 3
#     [01:59] Elevator floor: 0 | Passenger 9 requests a pickup at floor 2
#     [02:00] Elevator floor: 1 | Moving up to floor 1
#     [02:00] Elevator floor: 2 | Moving up to floor 2
#     [02:01] Elevator floor: 2 | Picked up P9(2 --> 3) (wait time: 1.1 min)
#     [02:01] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:01] Elevator floor: 3 | Moving up to floor 3
#     [02:01] Elevator floor: 3 | Dropped off P9(2 --> 3) (travel time: 1.6 min)
# [02:17] Passenger 10 appears at floor 5, wants to go to 4
#     [02:17] Elevator floor: 3 | Passenger 10 requests a pickup at floor 5
#     [02:18] Elevator floor: 4 | Moving up to floor 4
#     [02:19] Elevator floor: 5 | Moving up to floor 5
#     [02:19] Elevator floor: 5 | Picked up P10(5 --> 4) (wait time: 1.8 min)
#     [02:19] Elevator floor: 5 | No pickups pending, continuing current direction
#     [02:19] Elevator floor: 6 | Moving up to floor 6
#     [02:20] Elevator floor: 6 | No pickups pending, continuing current direction
#     [02:20] Elevator floor: 7 | Moving up to floor 7
#     [02:20] Elevator floor: 7 | No pickups pending, continuing current direction
#     [02:20] Elevator floor: 6 | Moving down to floor 6
#     [08:25] Elevator floor: 1 | Moving down to floor 1
#     [08:25] Elevator floor: 1 | Elevator full, P40(1 --> 5) must wait
#     [08:25] Elevator floor: 1 | Elevator full, P41(1 --> 3) must wait
#     [08:25] Elevator floor: 2 | Moving up to floor 2
#     [08:26] Elevator floor: 3 | Moving up to floor 3
# [08:26] Passenger 45 appears at floor 0, wants to go to 2
#     [08:26] Elevator floor: 3 | Passenger 45 requests a pickup at floor 0
#     [08:26] Elevator floor: 4 | Moving up to floor 4
# [08:26] Passenger 46 appears at floor 6, wants to go to 1
#     [08:26] Elevator floor: 4 | Passenger 46 requests a pickup at floor 6
#     [08:27] Elevator floor: 5 | Moving up to floor 5
#     [08:27] Elevator floor: 6 | Moving up to floor 6
# [08:27] Passenger 47 appears at floor 4, wants to go to 7
#     [08:27] Elevator floor: 6 | Passenger 47 requests a pickup at floor 4
#     [08:28] Elevator floor: 6 | Dropped off P39(5 --> 6) (travel time: 7.5 min)
#     [08:28] Elevator floor: 6 | Picked up P43(6 --> 0) (wait time: 3.2 min)
#     [08:28] Elevator floor: 6 | Elevator full, P46(6 --> 1) must wait
#     [08:28] Elevator floor: 7 | Moving up to floor 7
# [08:28] Passenger 48 appears at floor 2, wants to go to 4
#     [08:28] Elevator floor: 7 | Passenger 48 requests a pickup at floor 2
#     [08:28] Elevator floor: 7 | Elevator full, P42(7 --> 4) must wait
#     [08:28] Elevator floor: 6 | Moving down toward floor 0
#     [08:28] Elevator floor: 6 | Moving down to floor 6
#     [08:29] Elevator floor: 5 | Moving down toward floor 0
#     [08:29] Elevator floor: 5 | Moving down to floor 5
# [08:29] Passenger 49 appears at floor 1, wants to go to 3
#     [08:29] Elevator floor: 5 | Passenger 49 requests a pickup at floor 1
# [08:29] Passenger 50 appears at floor 7, wants to go to 6
#     [08:29] Elevator floor: 5 | Passenger 50 requests a pickup at floor 7
#     [08:29] Elevator floor: 4 | Moving down toward floor 0
#     [08:29] Elevator floor: 4 | Moving down to floor 4
#     [08:30] Elevator floor: 4 | Elevator full, P47(4 --> 7) must wait
#     [08:30] Elevator floor: 3 | Moving down toward floor 0
#     [08:30] Elevator floor: 3 | Moving down to floor 3
#     [08:30] Elevator floor: 2 | Moving down toward floor 0
#     [08:30] Elevator floor: 2 | Moving down to floor 2
#     [08:31] Elevator floor: 2 | Elevator full, P48(2 --> 4) must wait
#     [08:31] Elevator floor: 1 | Moving down toward floor 0
#     [08:31] Elevator floor: 1 | Moving down to floor 1
# [08:31] Passenger 51 appears at floor 7, wants to go to 6
#     [08:31] Elevator floor: 1 | Passenger 51 requests a pickup at floor 7
#     [08:31] Elevator floor: 1 | Elevator full, P49(1 --> 3) must wait
#     [08:31] Elevator floor: 0 | Moving down toward floor 0
#     [08:31] Elevator floor: 0 | Moving down to floor 0
#     [08:32] Elevator floor: 0 | Dropped off P25(3 --> 0) (travel time: 27.2 min)
#     [08:32] Elevator floor: 0 | Dropped off P37(4 --> 0) (travel time: 13.8 min)
#     [08:32] Elevator floor: 0 | Dropped off P38(1 --> 0) (travel time: 13.2 min)
#     [09:09] Elevator floor: 4 | Moving down toward floor 4
#     [09:09] Elevator floor: 4 | Moving down to floor 4
#     [09:10] Elevator floor: 4 | Picked up P53(4 --> 5) (wait time: 1.6 min)
#     [09:10] Elevator floor: 4 | No pickups pending, continuing current direction
#     [09:10] Elevator floor: 3 | Moving down to floor 3
#     [09:10] Elevator floor: 3 | No pickups pending, continuing current direction
#     [09:10] Elevator floor: 2 | Moving down to floor 2
#     [09:11] Elevator floor: 2 | No pickups pending, continuing current direction
#     [09:11] Elevator floor: 1 | Moving down to floor 1
#     [09:11] Elevator floor: 1 | No pickups pending, continuing current direction
#     [09:11] Elevator floor: 0 | Moving down to floor 0
#     [09:12] Elevator floor: 0 | No pickups pending, continuing current direction
#     [09:12] Elevator floor: 1 | Moving up to floor 1
#     [09:12] Elevator floor: 1 | No pickups pending, continuing current direction
#     [09:12] Elevator floor: 2 | Moving up to floor 2
#     [09:13] Elevator floor: 2 | No pickups pending, continuing current direction
#     [09:13] Elevator floor: 3 | Moving up to floor 3
#     [09:13] Elevator floor: 3 | No pickups pending, continuing current direction
#     [09:13] Elevator floor: 4 | Moving up to floor 4
#     [09:14] Elevator floor: 4 | No pickups pending, continuing current direction
#     [09:14] Elevator floor: 5 | Moving up to floor 5
#     [09:14] Elevator floor: 5 | Dropped off P53(4 --> 5) (travel time: 6.1 min)
# [09:16] Passenger 54 appears at floor 0, wants to go to 6
#     [09:16] Elevator floor: 5 | Passenger 54 requests a pickup at floor 0
#     [09:17] Elevator floor: 4 | Moving down toward floor 0
#     [09:17] Elevator floor: 4 | Moving down to floor 4
#     [09:18] Elevator floor: 3 | Moving down toward floor 0
#     [09:18] Elevator floor: 3 | Moving down to floor 3
#     [09:18] Elevator floor: 2 | Moving down toward floor 0
#     [09:18] Elevator floor: 2 | Moving down to floor 2
#     [09:19] Elevator floor: 1 | Moving down toward floor 0
#     [09:19] Elevator floor: 1 | Moving down to floor 1
#     [09:19] Elevator floor: 0 | Moving down toward floor 0
#     [09:19] Elevator floor: 0 | Moving down to floor 0
#     [09:20] Elevator floor: 0 | Picked up P54(0 --> 6) (wait time: 3.0 min)
#     [09:20] Elevator floor: 0 | No pickups pending, continuing current direction
#     [09:20] Elevator floor: 1 | Moving up to floor 1
# [09:20] Passenger 55 appears at floor 7, wants to go to 4
#     [09:20] Elevator floor: 1 | Passenger 55 requests a pickup at floor 7
#     [09:20] Elevator floor: 2 | Moving up to floor 2
#     [09:21] Elevator floor: 3 | Moving up to floor 3
#     [09:21] Elevator floor: 4 | Moving up to floor 4
#     [09:22] Elevator floor: 5 | Moving up to floor 5
#     [09:22] Elevator floor: 6 | Moving up to floor 6
#     [09:23] Elevator floor: 6 | Dropped off P54(0 --> 6) (travel time: 6.0 min)
#     [09:23] Elevator floor: 7 | Moving up to floor 7
#     [09:23] Elevator floor: 7 | Picked up P55(7 --> 4) (wait time: 3.0 min)
#     [09:23] Elevator floor: 7 | No pickups pending, continuing current direction
#     [09:23] Elevator floor: 6 | Moving down to floor 6
#     [09:24] Elevator floor: 6 | No pickups pending, continuing current direction
#     [09:24] Elevator floor: 5 | Moving down to floor 5
#     [09:24] Elevator floor: 5 | No pickups pending, continuing current direction
#     [09:24] Elevator floor: 4 | Moving down to floor 4
#     [09:25] Elevator floor: 4 | Dropped off P55(7 --> 4) (travel time: 4.5 min)
# [10:04] Passenger 56 appears at floor 1, wants to go to 6
#     [10:04] Elevator floor: 4 | Passenger 56 requests a pickup at floor 1
#     [10:05] Elevator floor: 3 | Moving down toward floor 1
#     [10:05] Elevator floor: 3 | Moving down to floor 3
#     [10:05] Elevator floor: 2 | Moving down toward floor 1
#     [10:05] Elevator floor: 2 | Moving down to floor 2
#     [10:06] Elevator floor: 1 | Moving down toward floor 1
#     [10:06] Elevator floor: 1 | Moving down to floor 1
#     [10:06] Elevator floor: 1 | Picked up P56(1 --> 6) (wait time: 2.4 min)
#     [10:06] Elevator floor: 1 | No pickups pending, continuing current direction
#     [10:06] Elevator floor: 0 | Moving down to floor 0
#     [10:07] Elevator floor: 0 | No pickups pending, continuing current direction
#     [10:07] Elevator floor: 1 | Moving up to floor 1
#     [10:07] Elevator floor: 1 | No pickups pending, continuing current direction
#     [10:07] Elevator floor: 2 | Moving up to floor 2
#     [10:08] Elevator floor: 2 | No pickups pending, continuing current direction
#     [10:08] Elevator floor: 3 | Moving up to floor 3
#     [10:08] Elevator floor: 3 | No pickups pending, continuing current direction
#     [10:08] Elevator floor: 4 | Moving up to floor 4
#     [10:09] Elevator floor: 4 | No pickups pending, continuing current direction
#     [10:09] Elevator floor: 5 | Moving up to floor 5
#     [10:09] Elevator floor: 5 | No pickups pending, continuing current direction
#     [10:09] Elevator floor: 6 | Moving up to floor 6
#     [10:10] Elevator floor: 6 | Dropped off P56(1 --> 6) (travel time: 5.9 min)
# [10:19] Passenger 57 appears at floor 4, wants to go to 2
#     [10:19] Elevator floor: 6 | Passenger 57 requests a pickup at floor 4
#     [10:20] Elevator floor: 5 | Moving down toward floor 4
#     [10:20] Elevator floor: 5 | Moving down to floor 5
#     [10:20] Elevator floor: 4 | Moving down toward floor 4
#     [10:20] Elevator floor: 4 | Moving down to floor 4
#     [10:21] Elevator floor: 4 | Picked up P57(4 --> 2) (wait time: 1.5 min)
#     [10:21] Elevator floor: 4 | No pickups pending, continuing current direction
#     [10:21] Elevator floor: 3 | Moving down to floor 3
#     [10:21] Elevator floor: 3 | No pickups pending, continuing current direction
#     [10:21] Elevator floor: 2 | Moving down to floor 2
#     [10:22] Elevator floor: 2 | Dropped off P57(4 --> 2) (travel time: 2.5 min)
# [10:24] Passenger 58 appears at floor 1, wants to go to 7
#     [10:24] Elevator floor: 2 | Passenger 58 requests a pickup at floor 1
#     [10:25] Elevator floor: 1 | Moving down toward floor 1
#     [10:25] Elevator floor: 1 | Moving down to floor 1
#     [10:25] Elevator floor: 1 | Picked up P58(1 --> 7) (wait time: 1.1 min)
#     [10:25] Elevator floor: 1 | No pickups pending, continuing current direction
#     [10:25] Elevator floor: 0 | Moving down to floor 0
#     [10:26] Elevator floor: 0 | No pickups pending, continuing current direction
#     [10:26] Elevator floor: 1 | Moving up to floor 1
#     [10:26] Elevator floor: 1 | No pickups pending, continuing current direction
#     [10:26] Elevator floor: 2 | Moving up to floor 2
#     [10:27] Elevator floor: 2 | No pickups pending, continuing current direction
#     [10:27] Elevator floor: 3 | Moving up to floor 3
#     [10:27] Elevator floor: 3 | No pickups pending, continuing current direction
#     [10:27] Elevator floor: 4 | Moving up to floor 4
#     [10:28] Elevator floor: 4 | No pickups pending, continuing current direction
#     [10:28] Elevator floor: 5 | Moving up to floor 5
#     [10:28] Elevator floor: 5 | No pickups pending, continuing current direction
#     [10:28] Elevator floor: 6 | Moving up to floor 6
#     [10:29] Elevator floor: 6 | No pickups pending, continuing current direction
#     [10:29] Elevator floor: 7 | Moving up to floor 7
#     [10:29] Elevator floor: 7 | Dropped off P58(1 --> 7) (travel time: 5.1 min)
# [10:38] Passenger 59 appears at floor 4, wants to go to 7
#     [10:38] Elevator floor: 7 | Passenger 59 requests a pickup at floor 4
#     [10:38] Elevator floor: 6 | Moving down toward floor 4
#     [10:38] Elevator floor: 6 | Moving down to floor 6
#     [10:39] Elevator floor: 5 | Moving down toward floor 4
#     [10:39] Elevator floor: 5 | Moving down to floor 5
#     [10:39] Elevator floor: 4 | Moving down toward floor 4
#     [10:39] Elevator floor: 4 | Moving down to floor 4
#     [10:40] Elevator floor: 4 | Picked up P59(4 --> 7) (wait time: 1.6 min)
#     [10:40] Elevator floor: 4 | No pickups pending, continuing current direction
#     [10:40] Elevator floor: 3 | Moving down to floor 3
#     [10:40] Elevator floor: 3 | No pickups pending, continuing current direction
#     [10:40] Elevator floor: 2 | Moving down to floor 2
#     [10:41] Elevator floor: 2 | No pickups pending, continuing current direction
#     [10:41] Elevator floor: 1 | Moving down to floor 1
#     [10:41] Elevator floor: 1 | No pickups pending, continuing current direction
#     [10:41] Elevator floor: 0 | Moving down to floor 0
#     [10:42] Elevator floor: 0 | No pickups pending, continuing current direction
#     [10:42] Elevator floor: 1 | Moving up to floor 1
#     [10:42] Elevator floor: 1 | No pickups pending, continuing current direction
#     [10:42] Elevator floor: 2 | Moving up to floor 2
#     [10:43] Elevator floor: 2 | No pickups pending, continuing current direction
#     [10:43] Elevator floor: 3 | Moving up to floor 3
#     [10:43] Elevator floor: 3 | No pickups pending, continuing current direction
#     [10:43] Elevator floor: 4 | Moving up to floor 4
#     [10:44] Elevator floor: 4 | No pickups pending, continuing current direction
#     [10:44] Elevator floor: 5 | Moving up to floor 5
#     [10:44] Elevator floor: 5 | No pickups pending, continuing current direction
#     [10:44] Elevator floor: 6 | Moving up to floor 6
#     [10:45] Elevator floor: 6 | No pickups pending, continuing current direction
#     [10:45] Elevator floor: 7 | Moving up to floor 7
#     [10:45] Elevator floor: 7 | Dropped off P59(4 --> 7) (travel time: 7.1 min)
# [12:10] Passenger 60 appears at floor 0, wants to go to 4
#     [12:10] Elevator floor: 7 | Passenger 60 requests a pickup at floor 0
# [12:10] Passenger 61 appears at floor 1, wants to go to 3
#     [12:10] Elevator floor: 7 | Passenger 61 requests a pickup at floor 1
# ...
# [21:46] Passenger 420 appears at floor 6, wants to go to 1
#     [21:46] Elevator floor: 4 | Passenger 420 requests a pickup at floor 6
#     [21:47] Elevator floor: 4 | Picked up P418(4 --> 3) (wait time: 1.3 min)
#     [21:47] Elevator floor: 3 | Moving down toward floor 0
#     [21:47] Elevator floor: 3 | Moving down to floor 3
#     [21:47] Elevator floor: 3 | Dropped off P418(4 --> 3) (travel time: 1.8 min)
#     [21:47] Elevator floor: 2 | Moving down toward floor 0
#     [21:47] Elevator floor: 2 | Moving down to floor 2
#     [21:48] Elevator floor: 1 | Moving down toward floor 0
#     [21:48] Elevator floor: 1 | Moving down to floor 1
#     [21:48] Elevator floor: 0 | Moving down toward floor 0
#     [21:48] Elevator floor: 0 | Moving down to floor 0
#     [21:49] Elevator floor: 0 | Dropped off P415(3 --> 0) (travel time: 6.9 min)
#     [21:49] Elevator floor: 0 | Dropped off P416(5 --> 0) (travel time: 5.0 min)
#     [21:49] Elevator floor: 0 | Picked up P417(0 --> 6) (wait time: 4.7 min)
#     [21:49] Elevator floor: 0 | Picked up P419(0 --> 2) (wait time: 2.6 min)
#     [21:49] Elevator floor: 1 | Moving up to floor 1
#     [21:49] Elevator floor: 2 | Moving up to floor 2
#     [21:50] Elevator floor: 2 | Dropped off P419(0 --> 2) (travel time: 3.6 min)
#     [21:50] Elevator floor: 3 | Moving up to floor 3
#     [21:50] Elevator floor: 4 | Moving up to floor 4
#     [21:51] Elevator floor: 5 | Moving up to floor 5
#     [21:51] Elevator floor: 6 | Moving up to floor 6
# [21:51] Passenger 421 appears at floor 1, wants to go to 4
#     [21:51] Elevator floor: 6 | Passenger 421 requests a pickup at floor 1
#     [21:52] Elevator floor: 6 | Dropped off P417(0 --> 6) (travel time: 7.7 min)
#     [21:52] Elevator floor: 6 | Picked up P420(6 --> 1) (wait time: 5.3 min)
#     [21:52] Elevator floor: 5 | Moving down toward floor 1
#     [21:52] Elevator floor: 5 | Moving down to floor 5
#     [21:52] Elevator floor: 4 | Moving down toward floor 1
#     [21:52] Elevator floor: 4 | Moving down to floor 4
#     [21:53] Elevator floor: 3 | Moving down toward floor 1
#     [21:53] Elevator floor: 3 | Moving down to floor 3
#     [21:53] Elevator floor: 2 | Moving down toward floor 1
#     [21:53] Elevator floor: 2 | Moving down to floor 2
#     [21:54] Elevator floor: 1 | Moving down toward floor 1
#     [21:54] Elevator floor: 1 | Moving down to floor 1
# [21:54] Passenger 422 appears at floor 2, wants to go to 0
#     [21:54] Elevator floor: 1 | Passenger 422 requests a pickup at floor 2
# [21:54] Passenger 423 appears at floor 0, wants to go to 4
#     [21:54] Elevator floor: 1 | Passenger 423 requests a pickup at floor 0
#     [21:54] Elevator floor: 1 | Dropped off P420(6 --> 1) (travel time: 7.8 min)
#     [21:54] Elevator floor: 1 | Picked up P421(1 --> 4) (wait time: 2.8 min)
#     [21:54] Elevator floor: 2 | Moving up to floor 2
#     [21:55] Elevator floor: 2 | Picked up P422(2 --> 0) (wait time: 1.0 min)
#     [21:55] Elevator floor: 1 | Moving down toward floor 0
#     [21:55] Elevator floor: 1 | Moving down to floor 1
#     [21:55] Elevator floor: 0 | Moving down toward floor 0
#     [21:55] Elevator floor: 0 | Moving down to floor 0
# [21:55] Passenger 424 appears at floor 4, wants to go to 0
#     [21:55] Elevator floor: 0 | Passenger 424 requests a pickup at floor 4
#     [21:56] Elevator floor: 0 | Dropped off P422(2 --> 0) (travel time: 2.0 min)
#     [21:56] Elevator floor: 0 | Picked up P423(0 --> 4) (wait time: 1.6 min)
#     [21:56] Elevator floor: 1 | Moving up to floor 1
# [21:56] Passenger 425 appears at floor 5, wants to go to 2
#     [21:56] Elevator floor: 1 | Passenger 425 requests a pickup at floor 5
#     [21:56] Elevator floor: 2 | Moving up to floor 2
#     [21:57] Elevator floor: 3 | Moving up to floor 3
# [21:57] Passenger 426 appears at floor 7, wants to go to 4
#     [21:57] Elevator floor: 3 | Passenger 426 requests a pickup at floor 7
#     [21:57] Elevator floor: 4 | Moving up to floor 4
# [21:57] Passenger 427 appears at floor 5, wants to go to 6
#     [21:57] Elevator floor: 4 | Passenger 427 requests a pickup at floor 5
#     [21:58] Elevator floor: 4 | Dropped off P421(1 --> 4) (travel time: 6.3 min)
#     [21:58] Elevator floor: 4 | Dropped off P423(0 --> 4) (travel time: 3.6 min)
#     [21:58] Elevator floor: 4 | Picked up P424(4 --> 0) (wait time: 2.2 min)
#     [21:58] Elevator floor: 5 | Moving up to floor 5
# [21:58] Passenger 428 appears at floor 0, wants to go to 6
#     [21:58] Elevator floor: 5 | Passenger 428 requests a pickup at floor 0
#     [21:58] Elevator floor: 5 | Picked up P425(5 --> 2) (wait time: 2.5 min)
#     [21:58] Elevator floor: 5 | Picked up P427(5 --> 6) (wait time: 0.8 min)
#     [21:58] Elevator floor: 6 | Moving up to floor 6
# [21:58] Passenger 429 appears at floor 3, wants to go to 5
#     [21:58] Elevator floor: 6 | Passenger 429 requests a pickup at floor 3
#     [21:59] Elevator floor: 6 | Dropped off P427(5 --> 6) (travel time: 1.3 min)
#     [21:59] Elevator floor: 7 | Moving up to floor 7
# [21:59] Passenger 430 appears at floor 4, wants to go to 7
#     [21:59] Elevator floor: 7 | Passenger 430 requests a pickup at floor 4
#     [21:59] Elevator floor: 7 | Picked up P426(7 --> 4) (wait time: 2.2 min)
#     [21:59] Elevator floor: 6 | Moving down toward floor 0
#     [21:59] Elevator floor: 6 | Moving down to floor 6
# [21:59] Passenger 431 appears at floor 3, wants to go to 5
#     [21:59] Elevator floor: 6 | Passenger 431 requests a pickup at floor 3
# [21:59] Passenger 432 appears at floor 7, wants to go to 4
#     [21:59] Elevator floor: 6 | Passenger 432 requests a pickup at floor 7
# [21:59] Passenger 433 appears at floor 4, wants to go to 1
#     [21:59] Elevator floor: 6 | Passenger 433 requests a pickup at floor 4
#     [22:00] Elevator floor: 5 | Moving down toward floor 0
#     [22:00] Elevator floor: 5 | Moving down to floor 5
# [22:00] Passenger 434 appears at floor 3, wants to go to 4
#     [22:00] Elevator floor: 5 | Passenger 434 requests a pickup at floor 3
#     [22:00] Elevator floor: 4 | Moving down toward floor 0
#     [22:00] Elevator floor: 4 | Moving down to floor 4
#     [22:01] Elevator floor: 4 | Dropped off P426(7 --> 4) (travel time: 3.7 min)
#     [22:01] Elevator floor: 4 | Picked up P430(4 --> 7) (wait time: 1.9 min)
#     [22:01] Elevator floor: 4 | Picked up P433(4 --> 1) (wait time: 1.1 min)
#     [22:01] Elevator floor: 3 | Moving down toward floor 0
#     [22:01] Elevator floor: 3 | Moving down to floor 3
#     [22:01] Elevator floor: 3 | Elevator full, P429(3 --> 5) must wait
#     [22:01] Elevator floor: 3 | Elevator full, P431(3 --> 5) must wait
#     [22:01] Elevator floor: 3 | Elevator full, P434(3 --> 4) must wait
#     [22:01] Elevator floor: 2 | Moving down toward floor 0
#     [22:01] Elevator floor: 2 | Moving down to floor 2
#     [22:02] Elevator floor: 2 | Dropped off P425(5 --> 2) (travel time: 6.0 min)
#     [22:02] Elevator floor: 1 | Moving down toward floor 0
#     [22:02] Elevator floor: 1 | Moving down to floor 1
#     [22:02] Elevator floor: 1 | Dropped off P433(4 --> 1) (travel time: 2.6 min)
#     [22:02] Elevator floor: 0 | Moving down toward floor 0
#     [22:02] Elevator floor: 0 | Moving down to floor 0
#     [22:03] Elevator floor: 0 | Dropped off P424(4 --> 0) (travel time: 7.2 min)
#     [22:03] Elevator floor: 0 | Picked up P428(0 --> 6) (wait time: 4.8 min)
#     [22:03] Elevator floor: 1 | Moving up to floor 1
#     [22:03] Elevator floor: 2 | Moving up to floor 2
#     [22:04] Elevator floor: 3 | Moving up to floor 3
#     [22:04] Elevator floor: 4 | Moving up to floor 4
#     [22:05] Elevator floor: 5 | Moving up to floor 5
#     [22:05] Elevator floor: 6 | Moving up to floor 6
#     [22:06] Elevator floor: 6 | Dropped off P428(0 --> 6) (travel time: 7.8 min)
#     [22:06] Elevator floor: 7 | Moving up to floor 7
#     [22:06] Elevator floor: 7 | Dropped off P430(4 --> 7) (travel time: 7.4 min)
#     [22:06] Elevator floor: 7 | Picked up P432(7 --> 4) (wait time: 6.7 min)
#     [22:06] Elevator floor: 7 | No pickups pending, continuing current direction
#     [22:06] Elevator floor: 6 | Moving down to floor 6
#     [22:07] Elevator floor: 6 | No pickups pending, continuing current direction
#     [22:07] Elevator floor: 5 | Moving down to floor 5
#     [22:07] Elevator floor: 5 | No pickups pending, continuing current direction
#     [22:07] Elevator floor: 4 | Moving down to floor 4
#     [22:08] Elevator floor: 4 | Dropped off P432(7 --> 4) (travel time: 8.2 min)
# [22:22] Passenger 435 appears at floor 1, wants to go to 3
#     [22:22] Elevator floor: 4 | Passenger 435 requests a pickup at floor 1
#     [22:23] Elevator floor: 3 | Moving down toward floor 1
#     [22:23] Elevator floor: 3 | Moving down to floor 3
#     [22:23] Elevator floor: 2 | Moving down toward floor 1
#     [22:23] Elevator floor: 2 | Moving down to floor 2
#     [22:24] Elevator floor: 1 | Moving down toward floor 1
#     [22:24] Elevator floor: 1 | Moving down to floor 1
#     [22:24] Elevator floor: 1 | Picked up P435(1 --> 3) (wait time: 1.9 min)
#     [22:24] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:24] Elevator floor: 0 | Moving down to floor 0
#     [22:25] Elevator floor: 0 | No pickups pending, continuing current direction
#     [22
#     [22:59] Elevator floor: 6 | Moving down to floor 6
#     [23:00] Elevator floor: 6 | Dropped off P438(7 --> 6) (travel time: 4.0 min)
# [23:24] Passenger 439 appears at floor 1, wants to go to 0
#     [23:24] Elevator floor: 6 | Passenger 439 requests a pickup at floor 1
#     [23:25] Elevator floor: 5 | Moving down toward floor 1
#     [23:25] Elevator floor: 5 | Moving down to floor 5
#     [23:25] Elevator floor: 4 | Moving down toward floor 1
#     [23:25] Elevator floor: 4 | Moving down to floor 4
#     [23:26] Elevator floor: 3 | Moving down toward floor 1
#     [23:26] Elevator floor: 3 | Moving down to floor 3
#     [23:26] Elevator floor: 2 | Moving down toward floor 1
#     [23:26] Elevator floor: 2 | Moving down to floor 2
#     [23:27] Elevator floor: 1 | Moving down toward floor 1
#     [23:27] Elevator floor: 1 | Moving down to floor 1
#     [23:27] Elevator floor: 1 | Picked up P439(1 --> 0) (wait time: 3.2 min)
#     [23:27] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:27] Elevator floor: 0 | Moving down to floor 0
#     [23:28] Elevator floor: 0 | Dropped off P439(1 --> 0) (travel time: 3.7 min)
# [23:28] Passenger 440 appears at floor 1, wants to go to 6
#     [23:28] Elevator floor: 0 | Passenger 440 requests a pickup at floor 1
#     [23:29] Elevator floor: 1 | Moving up to floor 1
#     [23:29] Elevator floor: 1 | Picked up P440(1 --> 6) (wait time: 1.4 min)
#     [23:29] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:29] Elevator floor: 2 | Moving up to floor 2
#     [23:30] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:30] Elevator floor: 3 | Moving up to floor 3
#     [23:30] Elevator floor: 3 | No pickups pending, continuing current direction
#     [23:30] Elevator floor: 4 | Moving up to floor 4
#     [23:31] Elevator floor: 4 | No pickups pending, continuing current direction
#     [23:31] Elevator floor: 5 | Moving up to floor 5
#     [23:31] Elevator floor: 5 | No pickups pending, continuing current direction
#     [23:31] Elevator floor: 6 | Moving up to floor 6
#     [23:32] Elevator floor: 6 | Dropped off P440(1 --> 6) (travel time: 3.9 min)
# [23:34] Passenger 441 appears at floor 3, wants to go to 0
#     [23:34] Elevator floor: 6 | Passenger 441 requests a pickup at floor 3
#     [23:35] Elevator floor: 5 | Moving down toward floor 3
#     [23:35] Elevator floor: 5 | Moving down to floor 5
#     [23:35] Elevator floor: 4 | Moving down toward floor 3
#     [23:35] Elevator floor: 4 | Moving down to floor 4
#     [23:36] Elevator floor: 3 | Moving down toward floor 3
#     [23:36] Elevator floor: 3 | Moving down to floor 3
#     [23:36] Elevator floor: 3 | Picked up P441(3 --> 0) (wait time: 2.4 min)
#     [23:36] Elevator floor: 3 | No pickups pending, continuing current direction
#     [23:36] Elevator floor: 2 | Moving down to floor 2
#     [23:37] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:37] Elevator floor: 1 | Moving down to floor 1
#     [23:37] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:37] Elevator floor: 0 | Moving down to floor 0
#     [23:38] Elevator floor: 0 | Dropped off P441(3 --> 0) (travel time: 3.9 min)
#
# ==================================================
# SIMULATION STATISTICS
# ==================================================
# Total passengers served: 354
# Average wait time: 2.2 minutes
# Average travel time: 5.3 minutes
# Simulation duration: 1440 minutes (24.0 hours)
# total passengers [354]
# ==================================================
