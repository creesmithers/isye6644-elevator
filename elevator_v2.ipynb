# %%
# Import libraries

import simpy
import random

# Set Simulation Global Variables
PASSENGER_INTERVAL = 10
NUM_FLOORS = 3
MAX_CAPACITY = 4
MINUTES_IN_DAY = 24 * 60 # Total simulation time in minutes
SIM_TIME = MINUTES_IN_DAY # Total simulation time in minutes

# %%
def get_arrival_rate(current_time_minutes):
    
    """
    Returns the arrival rate (passengers per minute) based on time of day.
    Peak times:
    - 7:30-8:30 AM (450-510 minutes)
    - 12:00-1:00 PM (720-780 minutes) 
    - 5:00-10:00 PM (1020-1320 minutes)
    """
    
    # Convert time to minutes from midnight
    time_of_day = current_time_minutes % 1440
    
    # Morning rush: 7:30-8:30 AM
    if 450 <= time_of_day <= 510:
        return 0.5  # High arrival rate (1 passenger every 2 minutes on average)
    
    # Lunch rush: 12:00-1:00 PM
    elif 720 <= time_of_day <= 780:
        return 0.4  # High arrival rate (1 passenger every 2.5 minutes on average)
    
    # Evening rush: 5:00-10:00 PM
    elif 1020 <= time_of_day <= 1320:
        return 0.3  # Medium-high arrival rate (1 passenger every 3.3 minutes on average)
    
    # Off-peak hours
    else:
        return 0.05  # Low arrival rate (1 passenger every 20 minutes on average)

def time_to_string(minutes):
    """Convert minutes from midnight to HH:MM format"""
    hours = int(minutes // 60) % 24
    mins = int(minutes % 60)
    return f"{hours:02d}:{mins:02d}"

# %%
class Passenger:
    def __init__(self, pid, pickup, destination):
        self.id = pid
        self.pickup = pickup
        self.destination = destination
        # should add start time in system so we can track how long they are in the system
        self.start_time = None  # Track when passenger enters system
    
    def __repr__(self, color = '\033[97m'):         # changes representation of passenger to be easier to read
        return f"{color}P{self.id}({self.pickup} --> {self.destination})"

# %% [markdown]
# I want to change passenger_generator a little bit.
# This now has all passengers arriving at a rate of 1 / lambda.
#     The issue is floor 1 will have many more people arriving than floor 2, 3, ....
#     I think it would be reasonable to have X people arriving at floor 1 and then
#         floor 2 and 3 would have X/2 or if we have 5 floors each would have X / 4.
#             - Cree

# %%
def passenger_generator(env, elevator):
    # Start with pid 1
    pid = 1         
    
    while True:
        # Get current arrival rate based on time of day
        current_rate = get_arrival_rate(env.now)
        
        # Calculate inter-arrival time using exponential distribution
        if current_rate > 0:
            inter_arrival_time = random.expovariate(current_rate)
        else:
            # Default to 1 hour if rate is 0 
            inter_arrival_time = 60  
        
        yield env.timeout(inter_arrival_time)
        
        pickup = random.randint(0, NUM_FLOORS - 1)           # random floor
        destination = random.randint(0, NUM_FLOORS - 1)       # random destination
        while pickup == destination:
            destination = random.randint(0,2)
        
        passenger = Passenger(pid, pickup, destination) # create the passenger
        passenger.start_time = env.now  # Record start time
        current_time_str = time_to_string(env.now)
        print(f"[{current_time_str}] Passenger {pid} appears at floor {pickup}, wants to go to {destination}")
        elevator.request_pickup(passenger)              # request pickup from elevator
        pid +=1

# %% [markdown]
# Elevator currently has a log, pickup_requests, and a run function that onboards and offboards people. It, however, doesn't move up or down floors ¯\_(ツ)_/¯
#
# To start, I think we should go with a super simple:
#     if self.floor < num_floors:
#         floor += 1
#     else: floor -= 1
#     that way it goes all the way up and then goes all the way down. picking people up and dropping them off as it goes.

# %%
class Elevator:
    def __init__(self, env, num_floors, strategy = "nearest"):
        self.env = env
        self.floor = 0          # Start at ground floor (0)
        self.direction = 'up'   # up or down
        self.num_floors = num_floors # total
        self.pickup_requests = {floor: [] for floor in range(num_floors)}
        self.onboard = []
        self.strategy = strategy
        self.stats = {
            'total_passengers': 0,
            'total_wait_time': 0,
            'total_travel_time': 0
        }

    def log(self, message):
        current_time = time_to_string(self.env.now)
        print(f"    [{current_time}] Elevator floor: {self.floor} | {message}")

    def request_pickup(self, passenger):
        self.pickup_requests[passenger.pickup].append(passenger)
        self.log(f"Passenger {passenger.id} requests a pickup at floor {passenger.pickup}")

    def find_longest_waiting_request(self):
        longest_wait_time = -1
        target_floor = None
        for floor, passengers in self.pickup_requests.items():
            for p in passengers:
                wait_time = self.env.now - p.start_time
                if wait_time > longest_wait_time:
                    longest_wait_time = wait_time
                    target_floor = floor
        return target_floor

    def run_elevator(self):
        while True:
            # 1) Off-load passengers at current floor
            offboarding = [p for p in self.onboard if p.destination == self.floor]
            for p in offboarding:
                self.onboard.remove(p)
                travel_time = self.env.now - p.start_time
                self.stats['total_travel_time'] += travel_time
                self.stats['total_passengers'] += 1
                self.log(f"Dropped off {p} (travel time: {travel_time:.1f} min)")

            # 2) On-board passengers at current floor
            boarding = self.pickup_requests[self.floor]
            for p in boarding:
                if len(self.onboard) < MAX_CAPACITY:
                    self.onboard.append(p)
                    wait_time = self.env.now - p.start_time
                    self.stats['total_wait_time'] += wait_time
                    self.log(f"Picked up {p} (wait time: {wait_time:.1f} min)")
                else:
                    self.log(f"Elevator full, {p} must wait")
            
            self.pickup_requests[self.floor].clear()

            # 3) Move logic based on strategy
            if self.strategy == "longest_wait":
                target_floor = self.find_longest_waiting_request()
    
                if target_floor is not None and target_floor != self.floor:
                    if target_floor > self.floor:
                        self.direction = 'up'
                        self.floor += 1
                    elif target_floor < self.floor:
                        self.direction = 'down'
                        self.floor -= 1
                        self.log(f"Moving {self.direction} toward floor {target_floor}")
                else:
                # No passengers waiting → continue in current direction
                    self.log("No pickups pending, continuing current direction")
                    if self.direction == 'up':
                        if self.floor < self.num_floors - 1:
                            self.floor += 1
                        else:
                            self.direction = 'down'
                            self.floor -= 1
                    else:
                        if self.floor > 0:
                            self.floor -= 1
                        else:
                            self.direction = 'up'
                            self.floor += 1
            else:
            # Default nearest (up/down sweep)
                if self.direction == 'up':
                    if self.floor < self.num_floors - 1:
                        self.floor += 1
                    else:
                        self.direction = 'down'
                        self.floor -= 1
                else:
                    if self.floor > 0:
                        self.floor -= 1
                    else:
                        self.direction = 'up'
                        self.floor += 1
            self.log(f"Moving {self.direction} to floor {self.floor}")


# 4) Wait for travel time (e.g. 1 time-unit per floor)
            yield self.env.timeout(1)

# %%
def print_simulation_stats(elevator):
    """Print simulation statistics"""
    print("\n" + "="*50)
    print("SIMULATION STATISTICS")
    print("="*50)
    print(f"Total passengers served: {elevator.stats['total_passengers']}")
    if elevator.stats['total_passengers'] > 0:
        avg_wait_time = elevator.stats['total_wait_time'] / elevator.stats['total_passengers']
        avg_travel_time = elevator.stats['total_travel_time'] / elevator.stats['total_passengers']
        print(f"Average wait time: {avg_wait_time:.1f} minutes")
        print(f"Average travel time: {avg_travel_time:.1f} minutes")
    print(f"Simulation duration: {SIM_TIME} minutes ({SIM_TIME/60:.1f} hours)")
    print("="*50)

# %%
##  Test Cell   ##
##              ##
##################

# Run the simulation
if __name__ == "__main__":
    random.seed(23)
    env = simpy.Environment()
    elevator = Elevator(env, num_floors=NUM_FLOORS, strategy="longest_wait")  # or "nearest"

    
    # Start both processes
    env.process(passenger_generator(env, elevator))
    env.process(elevator.run_elevator())
    
    print(f"Starting 24-hour elevator simulation...")
    print(f"Simulation will run for {SIM_TIME} minutes ({SIM_TIME/60:.1f} hours)")
    print("-" * 50)
    
    env.run(until=SIM_TIME)
    
    print_simulation_stats(elevator)
# Out:
# Starting 24-hour elevator simulation...
# Simulation will run for 1440 minutes (24.0 hours)
# --------------------------------------------------
#     [00:00] Elevator floor: 0 | No pickups pending, continuing current direction
#     [00:00] Elevator floor: 1 | Moving up to floor 1
#     [00:01] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:01] Elevator floor: 2 | Moving up to floor 2
#     [00:02] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:02] Elevator floor: 1 | Moving down to floor 1
#     [00:03] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:03] Elevator floor: 0 | Moving down to floor 0
#     [00:04] Elevator floor: 0 | No pickups pending, continuing current direction
#     [00:04] Elevator floor: 1 | Moving up to floor 1
#     [00:05] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:05] Elevator floor: 2 | Moving up to floor 2
#     [00:06] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:06] Elevator floor: 1 | Moving down to floor 1
#     [00:07] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:07] Elevator floor: 0 | Moving down to floor 0
#     [00:08] Elevator floor: 0 | No pickups pending, continuing current direction
#     [00:08] Elevator floor: 1 | Moving up to floor 1
#     [00:09] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:09] Elevator floor: 2 | Moving up to floor 2
#     [00:10] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:10] Elevator floor: 1 | Moving down to floor 1
#     [00:11] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:11] Elevator floor: 0 | Moving down to floor 0
#     [00:12] Elevator floor: 0 | No pickups pending, continuing current direction
#     [00:12] Elevator floor: 1 | Moving up to floor 1
#     [00:13] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:13] Elevator floor: 2 | Moving up to floor 2
#     [00:14] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:14] Elevator floor: 1 | Moving down to floor 1
#     [00:15] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:15] Elevator floor: 0 | Moving down to floor 0
#     [00:16] Elevator floor: 0 | No pickups pending, continuing current direction
#     [00:16] Elevator floor: 1 | Moving up to floor 1
#     [00:17] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:17] Elevator floor: 2 | Moving up to floor 2
#     [00:18] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:18] Elevator floor: 1 | Moving down to floor 1
#     [00:19] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:19] Elevator floor: 0 | Moving down to floor 0
#     [00:20] Elevator floor: 0 | No pickups pending, continuing current direction
#     [00:20] Elevator floor: 1 | Moving up to floor 1
#     [00:21] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:21] Elevator floor: 2 | Moving up to floor 2
#     [00:22] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:22] Elevator floor: 1 | Moving down to floor 1
#     [00:23] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:23] Elevator floor: 0 | Moving down to floor 0
#     [00:24] Elevator floor: 0 | No pickups pending, continuing current direction
#     [00:24] Elevator floor: 1 | Moving up to floor 1
#     [00:25] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:25] Elevator floor: 2 | Moving up to floor 2
#     [00:26] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:26] Elevator floor: 1 | Moving down to floor 1
#     [00:27] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:27] Elevator floor: 0 | Moving down to floor 0
#     [00:28] Elevator floor: 0 | No pickups pending, continuing current direction
#     [00:28] Elevator floor: 1 | Moving up to floor 1
#     [00:29] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:29] Elevator floor: 2 | Moving up to floor 2
#     [00:30] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:30] Elevator floor: 1 | Moving down to floor 1
#     [00:31] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:31] Elevator floor: 0 | Moving down to floor 0
#     [00:32] Elevator floor: 0 | No pickups pending, continuing current direction
#     [00:32] Elevator floor: 1 | Moving up to floor 1
#     [00:33] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:33] Elevator floor: 2 | Moving up to floor 2
#     [00:34] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:34] Elevator floor: 1 | Moving down to floor 1
#     [00:35] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:35] Elevator floor: 0 | Moving down to floor 0
#     [00:36] Elevator floor: 0 | No pickups pending, continuing current direction
#     [00:36] Elevator floor: 1 | Moving up to floor 1
#     [00:37] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:37] Elevator floor: 2 | Moving up to floor 2
#     [00:38] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:38] Elevator floor: 1 | Moving down to floor 1
#     [00:39] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:39] Elevator floor: 0 | Moving down to floor 0
#     [00:40] Elevator floor: 0 | No pickups pending, continuing current direction
#     [00:40] Elevator floor: 1 | Moving up to floor 1
#     [00:41] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:41] Elevator floor: 2 | Moving up to floor 2
#     [00:42] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:42] Elevator floor: 1 | Moving down to floor 1
#     [00:43] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:43] Elevator floor: 0 | Moving down to floor 0
#     [00:44] Elevator floor: 0 | No pickups pending, continuing current direction
#     [00:44] Elevator floor: 1 | Moving up to floor 1
#     [00:45] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:45] Elevator floor: 2 | Moving up to floor 2
#     [00:46] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:46] Elevator floor: 1 | Moving down to floor 1
#     [00:47] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:47] Elevator floor: 0 | Moving down to floor 0
#     [00:48] Elevator floor: 0 | No pickups pending, continuing current direction
#     [00:48] Elevator floor: 1 | Moving up to floor 1
#     [00:49] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:49] Elevator floor: 2 | Moving up to floor 2
#     [00:50] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:50] Elevator floor: 1 | Moving down to floor 1
#     [00:51] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:51] Elevator floor: 0 | Moving down to floor 0
# [00:51] Passenger 1 appears at floor 1, wants to go to 0
#     [00:51] Elevator floor: 0 | Passenger 1 requests a pickup at floor 1
#     [00:52] Elevator floor: 1 | Moving up to floor 1
# [00:52] Passenger 2 appears at floor 1, wants to go to 2
#     [00:52] Elevator floor: 1 | Passenger 2 requests a pickup at floor 1
#     [00:53] Elevator floor: 1 | Picked up P1(1 --> 0) (wait time: 1.2 min)
#     [00:53] Elevator floor: 1 | Picked up P2(1 --> 2) (wait time: 0.9 min)
#     [00:53] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:53] Elevator floor: 2 | Moving up to floor 2
#     [00:54] Elevator floor: 2 | Dropped off P2(1 --> 2) (travel time: 1.9 min)
#     [00:54] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:54] Elevator floor: 1 | Moving down to floor 1
#     [00:55] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:55] Elevator floor: 0 | Moving down to floor 0
#     [00:56] Elevator floor: 0 | Dropped off P1(1 --> 0) (travel time: 4.2 min)
#     [00:56] Elevator floor: 0 | No pickups pending, continuing current direction
#     [00:56] Elevator floor: 1 | Moving up to floor 1
#     [00:57] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:57] Elevator floor: 2 | Moving up to floor 2
#     [00:58] Elevator floor: 2 | No pickups pending, continuing current direction
#     [00:58] Elevator floor: 1 | Moving down to floor 1
#     [00:59] Elevator floor: 1 | No pickups pending, continuing current direction
#     [00:59] Elevator floor: 0 | Moving down to floor 0
#     [01:00] Elevator floor: 0 | No pickups pending, continuing current direction
#     [01:00] Elevator floor: 1 | Moving up to floor 1
# [01:00] Passenger 3 appears at floor 2, wants to go to 0
#     [01:00] Elevator floor: 1 | Passenger 3 requests a pickup at floor 2
#     [01:01] Elevator floor: 2 | Moving up to floor 2
#     [01:02] Elevator floor: 2 | Picked up P3(2 --> 0) (wait time: 1.0 min)
#     [01:02] Elevator floor: 2 | No pickups pending, continuing current direction
#     [01:02] Elevator floor: 1 | Moving down to floor 1
#     [01:03] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:03] Elevator floor: 0 | Moving down to floor 0
#     [01:04] Elevator floor: 0 | Dropped off P3(2 --> 0) (travel time: 3.0 min)
#     [01:04] Elevator floor: 0 | No pickups pending, continuing current direction
#     [01:04] Elevator floor: 1 | Moving up to floor 1
#     [01:05] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:05] Elevator floor: 2 | Moving up to floor 2
#     [01:06] Elevator floor: 2 | No pickups pending, continuing current direction
#     [01:06] Elevator floor: 1 | Moving down to floor 1
#     [01:07] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:07] Elevator floor: 0 | Moving down to floor 0
# [01:07] Passenger 4 appears at floor 0, wants to go to 2
#     [01:07] Elevator floor: 0 | Passenger 4 requests a pickup at floor 0
#     [01:08] Elevator floor: 0 | Picked up P4(0 --> 2) (wait time: 0.8 min)
#     [01:08] Elevator floor: 0 | No pickups pending, continuing current direction
#     [01:08] Elevator floor: 1 | Moving up to floor 1
#     [01:09] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:09] Elevator floor: 2 | Moving up to floor 2
#     [01:10] Elevator floor: 2 | Dropped off P4(0 --> 2) (travel time: 2.8 min)
#     [01:10] Elevator floor: 2 | No pickups pending, continuing current direction
#     [01:10] Elevator floor: 1 | Moving down to floor 1
#     [01:11] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:11] Elevator floor: 0 | Moving down to floor 0
#     [01:12] Elevator floor: 0 | No pickups pending, continuing current direction
#     [01:12] Elevator floor: 1 | Moving up to floor 1
#     [01:13] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:13] Elevator floor: 2 | Moving up to floor 2
#     [01:14] Elevator floor: 2 | No pickups pending, continuing current direction
#     [01:14] Elevator floor: 1 | Moving down to floor 1
#     [01:15] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:15] Elevator floor: 0 | Moving down to floor 0
#     [01:16] Elevator floor: 0 | No pickups pending, continuing current direction
#     [01:16] Elevator floor: 1 | Moving up to floor 1
#     [01:17] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:17] Elevator floor: 2 | Moving up to floor 2
#     [01:18] Elevator floor: 2 | No pickups pending, continuing current direction
#     [01:18] Elevator floor: 1 | Moving down to floor 1
#     [01:19] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:19] Elevator floor: 0 | Moving down to floor 0
# [01:19] Passenger 5 appears at floor 0, wants to go to 2
#     [01:19] Elevator floor: 0 | Passenger 5 requests a pickup at floor 0
#     [01:20] Elevator floor: 0 | Picked up P5(0 --> 2) (wait time: 0.7 min)
#     [01:20] Elevator floor: 0 | No pickups pending, continuing current direction
#     [01:20] Elevator floor: 1 | Moving up to floor 1
#     [01:21] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:21] Elevator floor: 2 | Moving up to floor 2
#     [01:22] Elevator floor: 2 | Dropped off P5(0 --> 2) (travel time: 2.7 min)
#     [01:22] Elevator floor: 2 | No pickups pending, continuing current direction
#     [01:22] Elevator floor: 1 | Moving down to floor 1
#     [01:23] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:23] Elevator floor: 0 | Moving down to floor 0
#     [01:24] Elevator floor: 0 | No pickups pending, continuing current direction
#     [01:24] Elevator floor: 1 | Moving up to floor 1
#     [01:25] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:25] Elevator floor: 2 | Moving up to floor 2
#     [01:26] Elevator floor: 2 | No pickups pending, continuing current direction
#     [01:26] Elevator floor: 1 | Moving down to floor 1
#     [01:27] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:27] Elevator floor: 0 | Moving down to floor 0
#     [01:28] Elevator floor: 0 | No pickups pending, continuing current direction
#     [01:28] Elevator floor: 1 | Moving up to floor 1
#     [01:29] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:29] Elevator floor: 2 | Moving up to floor 2
#     [01:30] Elevator floor: 2 | No pickups pending, continuing current direction
#     [01:30] Elevator floor: 1 | Moving down to floor 1
#     [01:31] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:31] Elevator floor: 0 | Moving down to floor 0
#     [01:32] Elevator floor: 0 | No pickups pending, continuing current direction
#     [01:32] Elevator floor: 1 | Moving up to floor 1
#     [01:33] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:33] Elevator floor: 2 | Moving up to floor 2
# [01:33] Passenger 6 appears at floor 0, wants to go to 2
#     [01:33] Elevator floor: 2 | Passenger 6 requests a pickup at floor 0
#     [01:34] Elevator floor: 1 | Moving down toward floor 0
#     [01:34] Elevator floor: 1 | Moving down to floor 1
#     [01:35] Elevator floor: 0 | Moving down toward floor 0
#     [01:35] Elevator floor: 0 | Moving down to floor 0
#     [01:36] Elevator floor: 0 | Picked up P6(0 --> 2) (wait time: 2.9 min)
#     [01:36] Elevator floor: 0 | No pickups pending, continuing current direction
#     [01:36] Elevator floor: 1 | Moving up to floor 1
#     [01:37] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:37] Elevator floor: 2 | Moving up to floor 2
#     [01:38] Elevator floor: 2 | Dropped off P6(0 --> 2) (travel time: 4.9 min)
#     [01:38] Elevator floor: 2 | No pickups pending, continuing current direction
#     [01:38] Elevator floor: 1 | Moving down to floor 1
#     [01:39] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:39] Elevator floor: 0 | Moving down to floor 0
#     [01:40] Elevator floor: 0 | No pickups pending, continuing current direction
#     [01:40] Elevator floor: 1 | Moving up to floor 1
#     [01:41] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:41] Elevator floor: 2 | Moving up to floor 2
#     [01:42] Elevator floor: 2 | No pickups pending, continuing current direction
#     [01:42] Elevator floor: 1 | Moving down to floor 1
#     [01:43] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:43] Elevator floor: 0 | Moving down to floor 0
#     [01:44] Elevator floor: 0 | No pickups pending, continuing current direction
#     [01:44] Elevator floor: 1 | Moving up to floor 1
#     [01:45] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:45] Elevator floor: 2 | Moving up to floor 2
#     [01:46] Elevator floor: 2 | No pickups pending, continuing current direction
#     [01:46] Elevator floor: 1 | Moving down to floor 1
#     [01:47] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:47] Elevator floor: 0 | Moving down to floor 0
#     [01:48] Elevator floor: 0 | No pickups pending, continuing current direction
#     [01:48] Elevator floor: 1 | Moving up to floor 1
#     [01:49] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:49] Elevator floor: 2 | Moving up to floor 2
#     [01:50] Elevator floor: 2 | No pickups pending, continuing current direction
#     [01:50] Elevator floor: 1 | Moving down to floor 1
#     [01:51] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:51] Elevator floor: 0 | Moving down to floor 0
#     [01:52] Elevator floor: 0 | No pickups pending, continuing current direction
#     [01:52] Elevator floor: 1 | Moving up to floor 1
# [01:52] Passenger 7 appears at floor 1, wants to go to 0
#     [01:52] Elevator floor: 1 | Passenger 7 requests a pickup at floor 1
#     [01:53] Elevator floor: 1 | Picked up P7(1 --> 0) (wait time: 0.1 min)
#     [01:53] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:53] Elevator floor: 2 | Moving up to floor 2
#     [01:54] Elevator floor: 2 | No pickups pending, continuing current direction
#     [01:54] Elevator floor: 1 | Moving down to floor 1
#     [01:55] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:55] Elevator floor: 0 | Moving down to floor 0
#     [01:56] Elevator floor: 0 | Dropped off P7(1 --> 0) (travel time: 3.1 min)
#     [01:56] Elevator floor: 0 | No pickups pending, continuing current direction
#     [01:56] Elevator floor: 1 | Moving up to floor 1
#     [01:57] Elevator floor: 1 | No pickups pending, continuing current direction
#     [01:57] Elevator floor: 2 | Moving up to floor 2
# [01:57] Passenger 8 appears at floor 0, wants to go to 2
#     [01:57] Elevator floor: 2 | Passenger 8 requests a pickup at floor 0
#     [01:58] Elevator floor: 1 | Moving down toward floor 0
#     [01:58] Elevator floor: 1 | Moving down to floor 1
#     [01:59] Elevator floor: 0 | Moving down toward floor 0
#     [01:59] Elevator floor: 0 | Moving down to floor 0
#     [02:00] Elevator floor: 0 | Picked up P8(0 --> 2) (wait time: 2.5 min)
#     [02:00] Elevator floor: 0 | No pickups pending, continuing current direction
#     [02:00] Elevator floor: 1 | Moving up to floor 1
#     [02:01] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:01] Elevator floor: 2 | Moving up to floor 2
#     [02:02] Elevator floor: 2 | Dropped off P8(0 --> 2) (travel time: 4.5 min)
#     [02:02] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:02] Elevator floor: 1 | Moving down to floor 1
#     [02:03] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:03] Elevator floor: 0 | Moving down to floor 0
#     [02:04] Elevator floor: 0 | No pickups pending, continuing current direction
#     [02:04] Elevator floor: 1 | Moving up to floor 1
#     [02:05] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:05] Elevator floor: 2 | Moving up to floor 2
#     [02:06] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:06] Elevator floor: 1 | Moving down to floor 1
# [02:06] Passenger 9 appears at floor 0, wants to go to 2
#     [02:06] Elevator floor: 1 | Passenger 9 requests a pickup at floor 0
#     [02:07] Elevator floor: 0 | Moving down toward floor 0
#     [02:07] Elevator floor: 0 | Moving down to floor 0
#     [02:08] Elevator floor: 0 | Picked up P9(0 --> 2) (wait time: 1.3 min)
#     [02:08] Elevator floor: 0 | No pickups pending, continuing current direction
#     [02:08] Elevator floor: 1 | Moving up to floor 1
#     [02:09] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:09] Elevator floor: 2 | Moving up to floor 2
#     [02:10] Elevator floor: 2 | Dropped off P9(0 --> 2) (travel time: 3.3 min)
#     [02:10] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:10] Elevator floor: 1 | Moving down to floor 1
#     [02:11] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:11] Elevator floor: 0 | Moving down to floor 0
# [02:11] Passenger 10 appears at floor 2, wants to go to 1
#     [02:11] Elevator floor: 0 | Passenger 10 requests a pickup at floor 2
#     [02:12] Elevator floor: 1 | Moving up to floor 1
#     [02:13] Elevator floor: 2 | Moving up to floor 2
#     [02:14] Elevator floor: 2 | Picked up P10(2 --> 1) (wait time: 2.4 min)
#     [02:14] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:14] Elevator floor: 1 | Moving down to floor 1
#     [02:15] Elevator floor: 1 | Dropped off P10(2 --> 1) (travel time: 3.4 min)
#     [02:15] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:15] Elevator floor: 0 | Moving down to floor 0
#     [02:16] Elevator floor: 0 | No pickups pending, continuing current direction
#     [02:16] Elevator floor: 1 | Moving up to floor 1
#     [02:17] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:17] Elevator floor: 2 | Moving up to floor 2
#     [02:18] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:18] Elevator floor: 1 | Moving down to floor 1
#     [02:19] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:19] Elevator floor: 0 | Moving down to floor 0
#     [02:20] Elevator floor: 0 | No pickups pending, continuing current direction
#     [02:20] Elevator floor: 1 | Moving up to floor 1
#     [02:21] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:21] Elevator floor: 2 | Moving up to floor 2
#     [02:22] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:22] Elevator floor: 1 | Moving down to floor 1
#     [02:23] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:23] Elevator floor: 0 | Moving down to floor 0
#     [02:24] Elevator floor: 0 | No pickups pending, continuing current direction
#     [02:24] Elevator floor: 1 | Moving up to floor 1
#     [02:25] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:25] Elevator floor: 2 | Moving up to floor 2
#     [02:26] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:26] Elevator floor: 1 | Moving down to floor 1
#     [02:27] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:27] Elevator floor: 0 | Moving down to floor 0
#     [02:28] Elevator floor: 0 | No pickups pending, continuing current direction
#     [02:28] Elevator floor: 1 | Moving up to floor 1
# [02:28] Passenger 11 appears at floor 1, wants to go to 2
#     [02:28] Elevator floor: 1 | Passenger 11 requests a pickup at floor 1
#     [02:29] Elevator floor: 1 | Picked up P11(1 --> 2) (wait time: 0.7 min)
#     [02:29] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:29] Elevator floor: 2 | Moving up to floor 2
#     [02:30] Elevator floor: 2 | Dropped off P11(1 --> 2) (travel time: 1.7 min)
#     [02:30] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:30] Elevator floor: 1 | Moving down to floor 1
#     [02:31] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:31] Elevator floor: 0 | Moving down to floor 0
#     [02:32] Elevator floor: 0 | No pickups pending, continuing current direction
#     [02:32] Elevator floor: 1 | Moving up to floor 1
#     [02:33] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:33] Elevator floor: 2 | Moving up to floor 2
#     [02:34] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:34] Elevator floor: 1 | Moving down to floor 1
# [02:34] Passenger 12 appears at floor 1, wants to go to 2
#     [02:34] Elevator floor: 1 | Passenger 12 requests a pickup at floor 1
#     [02:35] Elevator floor: 1 | Picked up P12(1 --> 2) (wait time: 0.1 min)
#     [02:35] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:35] Elevator floor: 0 | Moving down to floor 0
#     [02:36] Elevator floor: 0 | No pickups pending, continuing current direction
#     [02:36] Elevator floor: 1 | Moving up to floor 1
# [02:36] Passenger 13 appears at floor 1, wants to go to 0
#     [02:36] Elevator floor: 1 | Passenger 13 requests a pickup at floor 1
#     [02:37] Elevator floor: 1 | Picked up P13(1 --> 0) (wait time: 0.3 min)
#     [02:37] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:37] Elevator floor: 2 | Moving up to floor 2
#     [02:38] Elevator floor: 2 | Dropped off P12(1 --> 2) (travel time: 3.1 min)
#     [02:38] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:38] Elevator floor: 1 | Moving down to floor 1
#     [02:39] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:39] Elevator floor: 0 | Moving down to floor 0
#     [02:40] Elevator floor: 0 | Dropped off P13(1 --> 0) (travel time: 3.3 min)
#     [02:40] Elevator floor: 0 | No pickups pending, continuing current direction
#     [02:40] Elevator floor: 1 | Moving up to floor 1
#     [02:41] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:41] Elevator floor: 2 | Moving up to floor 2
#     [02:42] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:42] Elevator floor: 1 | Moving down to floor 1
#     [02:43] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:43] Elevator floor: 0 | Moving down to floor 0
#     [02:44] Elevator floor: 0 | No pickups pending, continuing current direction
#     [02:44] Elevator floor: 1 | Moving up to floor 1
#     [02:45] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:45] Elevator floor: 2 | Moving up to floor 2
#     [02:46] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:46] Elevator floor: 1 | Moving down to floor 1
#     [02:47] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:47] Elevator floor: 0 | Moving down to floor 0
#     [02:48] Elevator floor: 0 | No pickups pending, continuing current direction
#     [02:48] Elevator floor: 1 | Moving up to floor 1
#     [02:49] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:49] Elevator floor: 2 | Moving up to floor 2
#     [02:50] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:50] Elevator floor: 1 | Moving down to floor 1
#     [02:51] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:51] Elevator floor: 0 | Moving down to floor 0
#     [02:52] Elevator floor: 0 | No pickups pending, continuing current direction
#     [02:52] Elevator floor: 1 | Moving up to floor 1
#     [02:53] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:53] Elevator floor: 2 | Moving up to floor 2
#     [02:54] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:54] Elevator floor: 1 | Moving down to floor 1
#     [02:55] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:55] Elevator floor: 0 | Moving down to floor 0
#     [02:56] Elevator floor: 0 | No pickups pending, continuing current direction
#     [02:56] Elevator floor: 1 | Moving up to floor 1
#     [02:57] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:57] Elevator floor: 2 | Moving up to floor 2
#     [02:58] Elevator floor: 2 | No pickups pending, continuing current direction
#     [02:58] Elevator floor: 1 | Moving down to floor 1
#     [02:59] Elevator floor: 1 | No pickups pending, continuing current direction
#     [02:59] Elevator floor: 0 | Moving down to floor 0
#     [03:00] Elevator floor: 0 | No pickups pending, continuing current direction
#     [03:00] Elevator floor: 1 | Moving up to floor 1
#     [03:01] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:01] Elevator floor: 2 | Moving up to floor 2
# [03:01] Passenger 14 appears at floor 2, wants to go to 1
#     [03:01] Elevator floor: 2 | Passenger 14 requests a pickup at floor 2
#     [03:02] Elevator floor: 2 | Picked up P14(2 --> 1) (wait time: 0.0 min)
#     [03:02] Elevator floor: 2 | No pickups pending, continuing current direction
#     [03:02] Elevator floor: 1 | Moving down to floor 1
#     [03:03] Elevator floor: 1 | Dropped off P14(2 --> 1) (travel time: 1.0 min)
#     [03:03] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:03] Elevator floor: 0 | Moving down to floor 0
#     [03:04] Elevator floor: 0 | No pickups pending, continuing current direction
#     [03:04] Elevator floor: 1 | Moving up to floor 1
#     [03:05] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:05] Elevator floor: 2 | Moving up to floor 2
#     [03:06] Elevator floor: 2 | No pickups pending, continuing current direction
#     [03:06] Elevator floor: 1 | Moving down to floor 1
#     [03:07] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:07] Elevator floor: 0 | Moving down to floor 0
#     [03:08] Elevator floor: 0 | No pickups pending, continuing current direction
#     [03:08] Elevator floor: 1 | Moving up to floor 1
#     [03:09] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:09] Elevator floor: 2 | Moving up to floor 2
#     [03:10] Elevator floor: 2 | No pickups pending, continuing current direction
#     [03:10] Elevator floor: 1 | Moving down to floor 1
#     [03:11] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:11] Elevator floor: 0 | Moving down to floor 0
#     [03:12] Elevator floor: 0 | No pickups pending, continuing current direction
#     [03:12] Elevator floor: 1 | Moving up to floor 1
#     [03:13] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:13] Elevator floor: 2 | Moving up to floor 2
#     [03:14] Elevator floor: 2 | No pickups pending, continuing current direction
#     [03:14] Elevator floor: 1 | Moving down to floor 1
#     [03:15] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:15] Elevator floor: 0 | Moving down to floor 0
#     [03:16] Elevator floor: 0 | No pickups pending, continuing current direction
#     [03:16] Elevator floor: 1 | Moving up to floor 1
#     [03:17] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:17] Elevator floor: 2 | Moving up to floor 2
#     [03:18] Elevator floor: 2 | No pickups pending, continuing current direction
#     [03:18] Elevator floor: 1 | Moving down to floor 1
#     [03:19] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:19] Elevator floor: 0 | Moving down to floor 0
#     [03:20] Elevator floor: 0 | No pickups pending, continuing current direction
#     [03:20] Elevator floor: 1 | Moving up to floor 1
#     [03:21] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:21] Elevator floor: 2 | Moving up to floor 2
#     [03:22] Elevator floor: 2 | No pickups pending, continuing current direction
#     [03:22] Elevator floor: 1 | Moving down to floor 1
#     [03:23] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:23] Elevator floor: 0 | Moving down to floor 0
#     [03:24] Elevator floor: 0 | No pickups pending, continuing current direction
#     [03:24] Elevator floor: 1 | Moving up to floor 1
# [03:24] Passenger 15 appears at floor 0, wants to go to 2
#     [03:24] Elevator floor: 1 | Passenger 15 requests a pickup at floor 0
#     [03:25] Elevator floor: 0 | Moving down toward floor 0
#     [03:25] Elevator floor: 0 | Moving down to floor 0
#     [03:26] Elevator floor: 0 | Picked up P15(0 --> 2) (wait time: 1.5 min)
#     [03:26] Elevator floor: 0 | No pickups pending, continuing current direction
#     [03:26] Elevator floor: 1 | Moving up to floor 1
#     [03:27] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:27] Elevator floor: 2 | Moving up to floor 2
#     [03:28] Elevator floor: 2 | Dropped off P15(0 --> 2) (travel time: 3.5 min)
#     [03:28] Elevator floor: 2 | No pickups pending, continuing current direction
#     [03:28] Elevator floor: 1 | Moving down to floor 1
#     [03:29] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:29] Elevator floor: 0 | Moving down to floor 0
#     [03:30] Elevator floor: 0 | No pickups pending, continuing current direction
#     [03:30] Elevator floor: 1 | Moving up to floor 1
#     [03:31] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:31] Elevator floor: 2 | Moving up to floor 2
#     [03:32] Elevator floor: 2 | No pickups pending, continuing current direction
#     [03:32] Elevator floor: 1 | Moving down to floor 1
# [03:32] Passenger 16 appears at floor 2, wants to go to 0
#     [03:32] Elevator floor: 1 | Passenger 16 requests a pickup at floor 2
#     [03:33] Elevator floor: 2 | Moving up to floor 2
#     [03:34] Elevator floor: 2 | Picked up P16(2 --> 0) (wait time: 1.7 min)
#     [03:34] Elevator floor: 2 | No pickups pending, continuing current direction
#     [03:34] Elevator floor: 1 | Moving down to floor 1
#     [03:35] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:35] Elevator floor: 0 | Moving down to floor 0
#     [03:36] Elevator floor: 0 | Dropped off P16(2 --> 0) (travel time: 3.7 min)
#     [03:36] Elevator floor: 0 | No pickups pending, continuing current direction
#     [03:36] Elevator floor: 1 | Moving up to floor 1
#     [03:37] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:37] Elevator floor: 2 | Moving up to floor 2
#     [03:38] Elevator floor: 2 | No pickups pending, continuing current direction
#     [03:38] Elevator floor: 1 | Moving down to floor 1
#     [03:39] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:39] Elevator floor: 0 | Moving down to floor 0
#     [03:40] Elevator floor: 0 | No pickups pending, continuing current direction
#     [03:40] Elevator floor: 1 | Moving up to floor 1
#     [03:41] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:41] Elevator floor: 2 | Moving up to floor 2
#     [03:42] Elevator floor: 2 | No pickups pending, continuing current direction
#     [03:42] Elevator floor: 1 | Moving down to floor 1
#     [03:43] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:43] Elevator floor: 0 | Moving down to floor 0
#     [03:44] Elevator floor: 0 | No pickups pending, continuing current direction
#     [03:44] Elevator floor: 1 | Moving up to floor 1
#     [03:45] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:45] Elevator floor: 2 | Moving up to floor 2
#     [03:46] Elevator floor: 2 | No pickups pending, continuing current direction
#     [03:46] Elevator floor: 1 | Moving down to floor 1
#     [03:47] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:47] Elevator floor: 0 | Moving down to floor 0
#     [03:48] Elevator floor: 0 | No pickups pending, continuing current direction
#     [03:48] Elevator floor: 1 | Moving up to floor 1
#     [03:49] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:49] Elevator floor: 2 | Moving up to floor 2
# [03:49] Passenger 17 appears at floor 0, wants to go to 1
#     [03:49] Elevator floor: 2 | Passenger 17 requests a pickup at floor 0
#     [03:50] Elevator floor: 1 | Moving down toward floor 0
#     [03:50] Elevator floor: 1 | Moving down to floor 1
# [03:50] Passenger 18 appears at floor 1, wants to go to 2
#     [03:50] Elevator floor: 1 | Passenger 18 requests a pickup at floor 1
#     [03:51] Elevator floor: 1 | Picked up P18(1 --> 2) (wait time: 0.4 min)
#     [03:51] Elevator floor: 0 | Moving down toward floor 0
#     [03:51] Elevator floor: 0 | Moving down to floor 0
#     [03:52] Elevator floor: 0 | Picked up P17(0 --> 1) (wait time: 2.2 min)
#     [03:52] Elevator floor: 0 | No pickups pending, continuing current direction
#     [03:52] Elevator floor: 1 | Moving up to floor 1
#     [03:53] Elevator floor: 1 | Dropped off P17(0 --> 1) (travel time: 3.2 min)
#     [03:53] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:53] Elevator floor: 2 | Moving up to floor 2
#     [03:54] Elevator floor: 2 | Dropped off P18(1 --> 2) (travel time: 3.4 min)
#     [03:54] Elevator floor: 2 | No pickups pending, continuing current direction
#     [03:54] Elevator floor: 1 | Moving down to floor 1
#     [03:55] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:55] Elevator floor: 0 | Moving down to floor 0
#     [03:56] Elevator floor: 0 | No pickups pending, continuing current direction
#     [03:56] Elevator floor: 1 | Moving up to floor 1
#     [03:57] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:57] Elevator floor: 2 | Moving up to floor 2
# [03:57] Passenger 19 appears at floor 2, wants to go to 1
#     [03:57] Elevator floor: 2 | Passenger 19 requests a pickup at floor 2
#     [03:58] Elevator floor: 2 | Picked up P19(2 --> 1) (wait time: 0.9 min)
#     [03:58] Elevator floor: 2 | No pickups pending, continuing current direction
#     [03:58] Elevator floor: 1 | Moving down to floor 1
#     [03:59] Elevator floor: 1 | Dropped off P19(2 --> 1) (travel time: 1.9 min)
#     [03:59] Elevator floor: 1 | No pickups pending, continuing current direction
#     [03:59] Elevator floor: 0 | Moving down to floor 0
# [03:59] Passenger 20 appears at floor 1, wants to go to 2
#     [03:59] Elevator floor: 0 | Passenger 20 requests a pickup at floor 1
#     [04:00] Elevator floor: 1 | Moving up to floor 1
#     [04:01] Elevator floor: 1 | Picked up P20(1 --> 2) (wait time: 1.6 min)
#     [04:01] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:01] Elevator floor: 2 | Moving up to floor 2
#     [04:02] Elevator floor: 2 | Dropped off P20(1 --> 2) (travel time: 2.6 min)
#     [04:02] Elevator floor: 2 | No pickups pending, continuing current direction
#     [04:02] Elevator floor: 1 | Moving down to floor 1
#     [04:03] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:03] Elevator floor: 0 | Moving down to floor 0
#     [04:04] Elevator floor: 0 | No pickups pending, continuing current direction
#     [04:04] Elevator floor: 1 | Moving up to floor 1
#     [04:05] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:05] Elevator floor: 2 | Moving up to floor 2
#     [04:06] Elevator floor: 2 | No pickups pending, continuing current direction
#     [04:06] Elevator floor: 1 | Moving down to floor 1
# [04:06] Passenger 21 appears at floor 1, wants to go to 2
#     [04:06] Elevator floor: 1 | Passenger 21 requests a pickup at floor 1
#     [04:07] Elevator floor: 1 | Picked up P21(1 --> 2) (wait time: 0.3 min)
#     [04:07] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:07] Elevator floor: 0 | Moving down to floor 0
#     [04:08] Elevator floor: 0 | No pickups pending, continuing current direction
#     [04:08] Elevator floor: 1 | Moving up to floor 1
#     [04:09] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:09] Elevator floor: 2 | Moving up to floor 2
#     [04:10] Elevator floor: 2 | Dropped off P21(1 --> 2) (travel time: 3.3 min)
#     [04:10] Elevator floor: 2 | No pickups pending, continuing current direction
#     [04:10] Elevator floor: 1 | Moving down to floor 1
#     [04:11] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:11] Elevator floor: 0 | Moving down to floor 0
# [04:11] Passenger 22 appears at floor 0, wants to go to 2
#     [04:11] Elevator floor: 0 | Passenger 22 requests a pickup at floor 0
#     [04:12] Elevator floor: 0 | Picked up P22(0 --> 2) (wait time: 0.4 min)
#     [04:12] Elevator floor: 0 | No pickups pending, continuing current direction
#     [04:12] Elevator floor: 1 | Moving up to floor 1
#     [04:13] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:13] Elevator floor: 2 | Moving up to floor 2
#     [04:14] Elevator floor: 2 | Dropped off P22(0 --> 2) (travel time: 2.4 min)
#     [04:14] Elevator floor: 2 | No pickups pending, continuing current direction
#     [04:14] Elevator floor: 1 | Moving down to floor 1
#     [04:15] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:15] Elevator floor: 0 | Moving down to floor 0
#     [04:16] Elevator floor: 0 | No pickups pending, continuing current direction
#     [04:16] Elevator floor: 1 | Moving up to floor 1
#     [04:17] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:17] Elevator floor: 2 | Moving up to floor 2
#     [04:18] Elevator floor: 2 | No pickups pending, continuing current direction
#     [04:18] Elevator floor: 1 | Moving down to floor 1
#     [04:19] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:19] Elevator floor: 0 | Moving down to floor 0
#     [04:20] Elevator floor: 0 | No pickups pending, continuing current direction
#     [04:20] Elevator floor: 1 | Moving up to floor 1
#     [04:21] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:21] Elevator floor: 2 | Moving up to floor 2
#     [04:22] Elevator floor: 2 | No pickups pending, continuing current direction
#     [04:22] Elevator floor: 1 | Moving down to floor 1
#     [04:23] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:23] Elevator floor: 0 | Moving down to floor 0
#     [04:24] Elevator floor: 0 | No pickups pending, continuing current direction
#     [04:24] Elevator floor: 1 | Moving up to floor 1
#     [04:25] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:25] Elevator floor: 2 | Moving up to floor 2
#     [04:26] Elevator floor: 2 | No pickups pending, continuing current direction
#     [04:26] Elevator floor: 1 | Moving down to floor 1
#     [04:27] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:27] Elevator floor: 0 | Moving down to floor 0
#     [04:28] Elevator floor: 0 | No pickups pending, continuing current direction
#     [04:28] Elevator floor: 1 | Moving up to floor 1
#     [04:29] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:29] Elevator floor: 2 | Moving up to floor 2
#     [04:30] Elevator floor: 2 | No pickups pending, continuing current direction
#     [04:30] Elevator floor: 1 | Moving down to floor 1
#     [04:31] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:31] Elevator floor: 0 | Moving down to floor 0
#     [04:32] Elevator floor: 0 | No pickups pending, continuing current direction
#     [04:32] Elevator floor: 1 | Moving up to floor 1
#     [04:33] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:33] Elevator floor: 2 | Moving up to floor 2
#     [04:34] Elevator floor: 2 | No pickups pending, continuing current direction
#     [04:34] Elevator floor: 1 | Moving down to floor 1
#     [04:35] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:35] Elevator floor: 0 | Moving down to floor 0
#     [04:36] Elevator floor: 0 | No pickups pending, continuing current direction
#     [04:36] Elevator floor: 1 | Moving up to floor 1
#     [04:37] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:37] Elevator floor: 2 | Moving up to floor 2
#     [04:38] Elevator floor: 2 | No pickups pending, continuing current direction
#     [04:38] Elevator floor: 1 | Moving down to floor 1
#     [04:39] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:39] Elevator floor: 0 | Moving down to floor 0
#     [04:40] Elevator floor: 0 | No pickups pending, continuing current direction
#     [04:40] Elevator floor: 1 | Moving up to floor 1
#     [04:41] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:41] Elevator floor: 2 | Moving up to floor 2
#     [04:42] Elevator floor: 2 | No pickups pending, continuing current direction
#     [04:42] Elevator floor: 1 | Moving down to floor 1
# [04:42] Passenger 23 appears at floor 2, wants to go to 1
#     [04:42] Elevator floor: 1 | Passenger 23 requests a pickup at floor 2
#     [04:43] Elevator floor: 2 | Moving up to floor 2
#     [04:44] Elevator floor: 2 | Picked up P23(2 --> 1) (wait time: 1.7 min)
#     [04:44] Elevator floor: 2 | No pickups pending, continuing current direction
#     [04:44] Elevator floor: 1 | Moving down to floor 1
#     [04:45] Elevator floor: 1 | Dropped off P23(2 --> 1) (travel time: 2.7 min)
#     [04:45] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:45] Elevator floor: 0 | Moving down to floor 0
#     [04:46] Elevator floor: 0 | No pickups pending, continuing current direction
#     [04:46] Elevator floor: 1 | Moving up to floor 1
#     [04:47] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:47] Elevator floor: 2 | Moving up to floor 2
# [04:47] Passenger 24 appears at floor 2, wants to go to 0
#     [04:47] Elevator floor: 2 | Passenger 24 requests a pickup at floor 2
#     [04:48] Elevator floor: 2 | Picked up P24(2 --> 0) (wait time: 0.3 min)
#     [04:48] Elevator floor: 2 | No pickups pending, continuing current direction
#     [04:48] Elevator floor: 1 | Moving down to floor 1
#     [04:49] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:49] Elevator floor: 0 | Moving down to floor 0
#     [04:50] Elevator floor: 0 | Dropped off P24(2 --> 0) (travel time: 2.3 min)
#     [04:50] Elevator floor: 0 | No pickups pending, continuing current direction
#     [04:50] Elevator floor: 1 | Moving up to floor 1
#     [04:51] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:51] Elevator floor: 2 | Moving up to floor 2
#     [04:52] Elevator floor: 2 | No pickups pending, continuing current direction
#     [04:52] Elevator floor: 1 | Moving down to floor 1
#     [04:53] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:53] Elevator floor: 0 | Moving down to floor 0
#     [04:54] Elevator floor: 0 | No pickups pending, continuing current direction
#     [04:54] Elevator floor: 1 | Moving up to floor 1
#     [04:55] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:55] Elevator floor: 2 | Moving up to floor 2
#     [04:56] Elevator floor: 2 | No pickups pending, continuing current direction
#     [04:56] Elevator floor: 1 | Moving down to floor 1
#     [04:57] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:57] Elevator floor: 0 | Moving down to floor 0
#     [04:58] Elevator floor: 0 | No pickups pending, continuing current direction
#     [04:58] Elevator floor: 1 | Moving up to floor 1
#     [04:59] Elevator floor: 1 | No pickups pending, continuing current direction
#     [04:59] Elevator floor: 2 | Moving up to floor 2
#     [05:00] Elevator floor: 2 | No pickups pending, continuing current direction
#     [05:00] Elevator floor: 1 | Moving down to floor 1
#     [05:01] Elevator floor: 1 | No pickups pending, continuing current direction
#     [05:01] Elevator floor: 0 | Moving down to floor 0
#     [05:02] Elevator floor: 0 | No pickups pending, continuing current direction
#     [05:02] Elevator floor: 1 | Moving up to floor 1
#     [05:03] Elevator floor: 1 | No pickups pending, continuing current direction
#     [05:03] Elevator floor: 2 | Moving up to floor 2
#     [05:04] Elevator floor: 2 | No pickups pending, continuing current direction
#     [05:04] Elevator floor: 1 | Moving down to floor 1
#     [05:05] Elevator floor: 1 | No pickups pending, continuing current direction
#     [05:05] Elevator floor: 0 | Moving down to floor 0
#     [05:06] Elevator floor: 0 | No pickups pending, continuing current direction
#     [05:06] Elevator floor: 1 | Moving up to floor 1
#     [05:07] Elevator floor: 1 | No pickups pending, continuing current direction
#     [05:07] Elevator floor: 2 | Moving up to floor 2
#     [05:08] Elevator floor: 2 | No pickups pending, continuing current direction
#     [05:08] Elevator floor: 1 | Moving down to floor 1
# ...
#     [22:17] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:17] Elevator floor: 2 | Moving up to floor 2
#     [22:18] Elevator floor: 2 | No pickups pending, continuing current direction
#     [22:18] Elevator floor: 1 | Moving down to floor 1
#     [22:19] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:19] Elevator floor: 0 | Moving down to floor 0
#     [22:20] Elevator floor: 0 | No pickups pending, continuing current direction
#     [22:20] Elevator floor: 1 | Moving up to floor 1
#     [22:21] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:21] Elevator floor: 2 | Moving up to floor 2
#     [22:22] Elevator floor: 2 | No pickups pending, continuing current direction
#     [22:22] Elevator floor: 1 | Moving down to floor 1
#     [22:23] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:23] Elevator floor: 0 | Moving down to floor 0
#     [22:24] Elevator floor: 0 | No pickups pending, continuing current direction
#     [22:24] Elevator floor: 1 | Moving up to floor 1
#     [22:25] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:25] Elevator floor: 2 | Moving up to floor 2
#     [22:26] Elevator floor: 2 | No pickups pending, continuing current direction
#     [22:26] Elevator floor: 1 | Moving down to floor 1
#     [22:27] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:27] Elevator floor: 0 | Moving down to floor 0
#     [22:28] Elevator floor: 0 | No pickups pending, continuing current direction
#     [22:28] Elevator floor: 1 | Moving up to floor 1
# [22:28] Passenger 172 appears at floor 0, wants to go to 1
#     [22:28] Elevator floor: 1 | Passenger 172 requests a pickup at floor 0
#     [22:29] Elevator floor: 0 | Moving down toward floor 0
#     [22:29] Elevator floor: 0 | Moving down to floor 0
#     [22:30] Elevator floor: 0 | Picked up P172(0 --> 1) (wait time: 1.7 min)
#     [22:30] Elevator floor: 0 | No pickups pending, continuing current direction
#     [22:30] Elevator floor: 1 | Moving up to floor 1
#     [22:31] Elevator floor: 1 | Dropped off P172(0 --> 1) (travel time: 2.7 min)
#     [22:31] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:31] Elevator floor: 2 | Moving up to floor 2
#     [22:32] Elevator floor: 2 | No pickups pending, continuing current direction
#     [22:32] Elevator floor: 1 | Moving down to floor 1
# [22:32] Passenger 173 appears at floor 0, wants to go to 2
#     [22:32] Elevator floor: 1 | Passenger 173 requests a pickup at floor 0
#     [22:33] Elevator floor: 0 | Moving down toward floor 0
#     [22:33] Elevator floor: 0 | Moving down to floor 0
#     [22:34] Elevator floor: 0 | Picked up P173(0 --> 2) (wait time: 1.8 min)
#     [22:34] Elevator floor: 0 | No pickups pending, continuing current direction
#     [22:34] Elevator floor: 1 | Moving up to floor 1
#     [22:35] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:35] Elevator floor: 2 | Moving up to floor 2
#     [22:36] Elevator floor: 2 | Dropped off P173(0 --> 2) (travel time: 3.8 min)
#     [22:36] Elevator floor: 2 | No pickups pending, continuing current direction
#     [22:36] Elevator floor: 1 | Moving down to floor 1
#     [22:37] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:37] Elevator floor: 0 | Moving down to floor 0
#     [22:38] Elevator floor: 0 | No pickups pending, continuing current direction
#     [22:38] Elevator floor: 1 | Moving up to floor 1
#     [22:39] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:39] Elevator floor: 2 | Moving up to floor 2
#     [22:40] Elevator floor: 2 | No pickups pending, continuing current direction
#     [22:40] Elevator floor: 1 | Moving down to floor 1
#     [22:41] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:41] Elevator floor: 0 | Moving down to floor 0
#     [22:42] Elevator floor: 0 | No pickups pending, continuing current direction
#     [22:42] Elevator floor: 1 | Moving up to floor 1
#     [22:43] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:43] Elevator floor: 2 | Moving up to floor 2
#     [22:44] Elevator floor: 2 | No pickups pending, continuing current direction
#     [22:44] Elevator floor: 1 | Moving down to floor 1
#     [22:45] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:45] Elevator floor: 0 | Moving down to floor 0
#     [22:46] Elevator floor: 0 | No pickups pending, continuing current direction
#     [22:46] Elevator floor: 1 | Moving up to floor 1
#     [22:47] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:47] Elevator floor: 2 | Moving up to floor 2
#     [22:48] Elevator floor: 2 | No pickups pending, continuing current direction
#     [22:48] Elevator floor: 1 | Moving down to floor 1
#     [22:49] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:49] Elevator floor: 0 | Moving down to floor 0
#     [22:50] Elevator floor: 0 | No pickups pending, continuing current direction
#     [22:50] Elevator floor: 1 | Moving up to floor 1
#     [22:51] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:51] Elevator floor: 2 | Moving up to floor 2
# [22:51] Passenger 174 appears at floor 1, wants to go to 0
#     [22:51] Elevator floor: 2 | Passenger 174 requests a pickup at floor 1
#     [22:52] Elevator floor: 1 | Moving down toward floor 1
#     [22:52] Elevator floor: 1 | Moving down to floor 1
#     [22:53] Elevator floor: 1 | Picked up P174(1 --> 0) (wait time: 1.9 min)
#     [22:53] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:53] Elevator floor: 0 | Moving down to floor 0
#     [22:54] Elevator floor: 0 | Dropped off P174(1 --> 0) (travel time: 2.9 min)
#     [22:54] Elevator floor: 0 | No pickups pending, continuing current direction
#     [22:54] Elevator floor: 1 | Moving up to floor 1
#     [22:55] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:55] Elevator floor: 2 | Moving up to floor 2
#     [22:56] Elevator floor: 2 | No pickups pending, continuing current direction
#     [22:56] Elevator floor: 1 | Moving down to floor 1
#     [22:57] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:57] Elevator floor: 0 | Moving down to floor 0
#     [22:58] Elevator floor: 0 | No pickups pending, continuing current direction
#     [22:58] Elevator floor: 1 | Moving up to floor 1
#     [22:59] Elevator floor: 1 | No pickups pending, continuing current direction
#     [22:59] Elevator floor: 2 | Moving up to floor 2
#     [23:00] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:00] Elevator floor: 1 | Moving down to floor 1
#     [23:01] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:01] Elevator floor: 0 | Moving down to floor 0
#     [23:02] Elevator floor: 0 | No pickups pending, continuing current direction
#     [23:02] Elevator floor: 1 | Moving up to floor 1
#     [23:03] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:03] Elevator floor: 2 | Moving up to floor 2
#     [23:04] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:04] Elevator floor: 1 | Moving down to floor 1
#     [23:05] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:05] Elevator floor: 0 | Moving down to floor 0
#     [23:06] Elevator floor: 0 | No pickups pending, continuing current direction
#     [23:06] Elevator floor: 1 | Moving up to floor 1
#     [23:07] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:07] Elevator floor: 2 | Moving up to floor 2
#     [23:08] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:08] Elevator floor: 1 | Moving down to floor 1
#     [23:09] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:09] Elevator floor: 0 | Moving down to floor 0
# [23:09] Passenger 175 appears at floor 2, wants to go to 1
#     [23:09] Elevator floor: 0 | Passenger 175 requests a pickup at floor 2
#     [23:10] Elevator floor: 1 | Moving up to floor 1
#     [23:11] Elevator floor: 2 | Moving up to floor 2
#     [23:12] Elevator floor: 2 | Picked up P175(2 --> 1) (wait time: 2.5 min)
#     [23:12] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:12] Elevator floor: 1 | Moving down to floor 1
#     [23:13] Elevator floor: 1 | Dropped off P175(2 --> 1) (travel time: 3.5 min)
#     [23:13] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:13] Elevator floor: 0 | Moving down to floor 0
#     [23:14] Elevator floor: 0 | No pickups pending, continuing current direction
#     [23:14] Elevator floor: 1 | Moving up to floor 1
#     [23:15] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:15] Elevator floor: 2 | Moving up to floor 2
# [23:15] Passenger 176 appears at floor 0, wants to go to 2
#     [23:15] Elevator floor: 2 | Passenger 176 requests a pickup at floor 0
#     [23:16] Elevator floor: 1 | Moving down toward floor 0
#     [23:16] Elevator floor: 1 | Moving down to floor 1
#     [23:17] Elevator floor: 0 | Moving down toward floor 0
#     [23:17] Elevator floor: 0 | Moving down to floor 0
#     [23:18] Elevator floor: 0 | Picked up P176(0 --> 2) (wait time: 2.6 min)
#     [23:18] Elevator floor: 0 | No pickups pending, continuing current direction
#     [23:18] Elevator floor: 1 | Moving up to floor 1
#     [23:19] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:19] Elevator floor: 2 | Moving up to floor 2
# [23:19] Passenger 177 appears at floor 2, wants to go to 0
#     [23:19] Elevator floor: 2 | Passenger 177 requests a pickup at floor 2
#     [23:20] Elevator floor: 2 | Dropped off P176(0 --> 2) (travel time: 4.6 min)
#     [23:20] Elevator floor: 2 | Picked up P177(2 --> 0) (wait time: 0.8 min)
#     [23:20] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:20] Elevator floor: 1 | Moving down to floor 1
#     [23:21] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:21] Elevator floor: 0 | Moving down to floor 0
#     [23:22] Elevator floor: 0 | Dropped off P177(2 --> 0) (travel time: 2.8 min)
#     [23:22] Elevator floor: 0 | No pickups pending, continuing current direction
#     [23:22] Elevator floor: 1 | Moving up to floor 1
#     [23:23] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:23] Elevator floor: 2 | Moving up to floor 2
#     [23:24] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:24] Elevator floor: 1 | Moving down to floor 1
#     [23:25] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:25] Elevator floor: 0 | Moving down to floor 0
#     [23:26] Elevator floor: 0 | No pickups pending, continuing current direction
#     [23:26] Elevator floor: 1 | Moving up to floor 1
#     [23:27] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:27] Elevator floor: 2 | Moving up to floor 2
#     [23:28] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:28] Elevator floor: 1 | Moving down to floor 1
#     [23:29] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:29] Elevator floor: 0 | Moving down to floor 0
#     [23:30] Elevator floor: 0 | No pickups pending, continuing current direction
#     [23:30] Elevator floor: 1 | Moving up to floor 1
#     [23:31] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:31] Elevator floor: 2 | Moving up to floor 2
#     [23:32] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:32] Elevator floor: 1 | Moving down to floor 1
# [23:32] Passenger 178 appears at floor 1, wants to go to 2
#     [23:32] Elevator floor: 1 | Passenger 178 requests a pickup at floor 1
#     [23:33] Elevator floor: 1 | Picked up P178(1 --> 2) (wait time: 0.2 min)
#     [23:33] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:33] Elevator floor: 0 | Moving down to floor 0
#     [23:34] Elevator floor: 0 | No pickups pending, continuing current direction
#     [23:34] Elevator floor: 1 | Moving up to floor 1
#     [23:35] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:35] Elevator floor: 2 | Moving up to floor 2
#     [23:36] Elevator floor: 2 | Dropped off P178(1 --> 2) (travel time: 3.2 min)
#     [23:36] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:36] Elevator floor: 1 | Moving down to floor 1
#     [23:37] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:37] Elevator floor: 0 | Moving down to floor 0
#     [23:38] Elevator floor: 0 | No pickups pending, continuing current direction
#     [23:38] Elevator floor: 1 | Moving up to floor 1
#     [23:39] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:39] Elevator floor: 2 | Moving up to floor 2
#     [23:40] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:40] Elevator floor: 1 | Moving down to floor 1
#     [23:41] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:41] Elevator floor: 0 | Moving down to floor 0
#     [23:42] Elevator floor: 0 | No pickups pending, continuing current direction
#     [23:42] Elevator floor: 1 | Moving up to floor 1
#     [23:43] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:43] Elevator floor: 2 | Moving up to floor 2
#     [23:44] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:44] Elevator floor: 1 | Moving down to floor 1
#     [23:45] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:45] Elevator floor: 0 | Moving down to floor 0
#     [23:46] Elevator floor: 0 | No pickups pending, continuing current direction
#     [23:46] Elevator floor: 1 | Moving up to floor 1
#     [23:47] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:47] Elevator floor: 2 | Moving up to floor 2
#     [23:48] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:48] Elevator floor: 1 | Moving down to floor 1
#     [23:49] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:49] Elevator floor: 0 | Moving down to floor 0
#     [23:50] Elevator floor: 0 | No pickups pending, continuing current direction
#     [23:50] Elevator floor: 1 | Moving up to floor 1
#     [23:51] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:51] Elevator floor: 2 | Moving up to floor 2
#     [23:52] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:52] Elevator floor: 1 | Moving down to floor 1
#     [23:53] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:53] Elevator floor: 0 | Moving down to floor 0
#     [23:54] Elevator floor: 0 | No pickups pending, continuing current direction
#     [23:54] Elevator floor: 1 | Moving up to floor 1
#     [23:55] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:55] Elevator floor: 2 | Moving up to floor 2
#     [23:56] Elevator floor: 2 | No pickups pending, continuing current direction
#     [23:56] Elevator floor: 1 | Moving down to floor 1
#     [23:57] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:57] Elevator floor: 0 | Moving down to floor 0
#     [23:58] Elevator floor: 0 | No pickups pending, continuing current direction
#     [23:58] Elevator floor: 1 | Moving up to floor 1
#     [23:59] Elevator floor: 1 | No pickups pending, continuing current direction
#     [23:59] Elevator floor: 2 | Moving up to floor 2
#
# ==================================================
# SIMULATION STATISTICS
# ==================================================
# Total passengers served: 177
# Average wait time: 1.4 minutes
# Average travel time: 3.2 minutes
# Simulation duration: 1440 minutes (24.0 hours)
# ==================================================
